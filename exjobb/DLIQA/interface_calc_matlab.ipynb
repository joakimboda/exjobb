# %%
import Bio
from Bio.PDB import *
import sys
import re
#import matplotlib.pyplot as plt
#from matplotlib import cm
import math
import numpy as np
import os

import pandas
import multiprocessing

import shutil


#This is for removing Bio.python warnings
import warnings
from Bio import BiopythonWarning
warnings.simplefilter('ignore', BiopythonWarning)

ele='D'
pro=['C','N','O','S','H']
lig=['C','N','O','S','P','F','Cl','Br','I','H']

try:
    list_index_p=pro.index(atom1.get_name())
    if list_index_p==4:

    else:
        ele=str(list_index_p+1)
        outfile.write('0'+' '+ele+' '+x+' '+y+' '+z+'\n')
except:
    'odd'
    
try:
    list_index_l=pro.index(atom2.get_name())
    if list_index_p==9:
        
    else:
        ele=str(list_index_l+1)
        outfile.write('0'+' '+ele+' '+x+' '+y+' '+z+'\n')
except:
    'odd'

#print filter(lambda x: ele in x, g)

# %%
def GenerateFeature_alpha_2D(protein_name, working_dir):
    
    
#if 'true':
    thr = 12.0
    rs = 0.1
    lth = int(thr/rs)
    small = 0.01

    OrderedName = np.load('temp/PerformanceOrderAlphaHand.npy')
    
    d=0
    for x in OrderedName:
        d=d+1
        print x
    print d
    X = np.zeros([16, lth, 128], float)

    InFile = open('temp/1a8i_protein_alpha.pkl')
    BarCollection = pickle.load(InFile)
    for j in range(len(OrderedName)):
        plname = OrderedName[j]; pname, lname = plname.split('_');
        f_p_i_j = np.zeros([8,lth], float)
        f_pl_i_j = np.zeros([8,lth], float)
        if 'pro_'+pname in BarCollection.keys():
            Bars = BarCollection['pro_'+pname]
            for Bar in Bars:
                if Bar[1] >= thr: continue
                if Bar[2] >= thr: Bar[2] = thr-0.00001
                bid = min(int(np.floor(Bar[1]/rs)), lth-1)
                did = min(int(np.floor(Bar[2]/rs)), lth-1)
                if Bar[0] == 0:
                    f_p_i_j[0,did] += 1.0
                    f_p_i_j[1,bid:did+1] += 1.0
                elif Bar[0] == 1:
                    f_p_i_j[2,bid] += 1.0
                    f_p_i_j[3,did] += 1.0
                    f_p_i_j[4,bid:did+1] += 1.0
                elif Bar[0] == 2:
                    f_p_i_j[5,bid] += 1.0
                    f_p_i_j[6,did] += 1.0
                    f_p_i_j[7,bid:did+1] += 1.0
        if 'com_'+plname in BarCollection.keys():
            Bars = BarCollection['com_'+plname]
            for Bar in Bars:
                if Bar[1] >= thr: continue
                if Bar[2] >= thr: Bar[2] = thr-0.00001
                bid = min(int(np.floor(Bar[1]/rs)), lth-1)
                did = min(int(np.floor(Bar[2]/rs)), lth-1)
                if Bar[0] == 0:
                    f_pl_i_j[0,did] += 1.0
                    f_pl_i_j[1,bid:did+1] += 1.0
                elif Bar[0] == 1:
                    f_pl_i_j[2,bid] += 1.0
                    f_pl_i_j[3,did] += 1.0
                    f_pl_i_j[4,bid:did+1] += 1.0
                elif Bar[0] == 2:
                    f_pl_i_j[5,bid] += 1.0
                    f_pl_i_j[6,did] += 1.0
                    f_pl_i_j[7,bid:did+1] += 1.0
        f_df_i_j = f_pl_i_j[:,:] - f_p_i_j[:,:]
        X[0:8,:,j] = f_pl_i_j[:,:]; X[8:16,:,j] = f_df_i_j[:,:]

    OutFile = open(working_dir+'/'+protein_name+'_feature_complex_alpha_2DCNN.npy', 'w')
    np.save(OutFile, X)
    OutFile.close()

# %%
def element_classification(outfile,comp) :
    
    ProEleCollection = [['C'],['N'],['O'],['S'],['C','N'],['C','O'],['N','O'],['C','N','O'],['C','N','O','S']]
    LigEleCollection = [['C'],['N'],['O'],['S'],['C','N'],['C','O'],['C','S'],['N','O'],['N','S'],['O','S'],['C','N','O'],['C','N','S'],['C','O','S'],['N','O','S'],['C','N','O','S'],['C','N','O','S','P','F','Cl','Br','I']]
    
    
    PRO = comp['PROT']; LIG = comp['LIG'];   

    for epcount,ep in enumerate(ProEleCollection):
        for elcount,el in enumerate(LigEleCollection):
            
            propts = []
            for a in range(len(PRO)):
                if PRO[a][0].replace(" ","") in ep:
                    propts.append([PRO[a][0], PRO[a][1], PRO[a][2], PRO[a][3] ])
            ligpts = []
            for a in range(len(LIG)):
                if LIG[a][0].replace(" ","") in el:
                    ligpts.append([LIG[a][0], LIG[a][1], LIG[a][2], LIG[a][3] ])
            if len(propts) + len(ligpts) > 3:
                pname = ''
                for eep in ep:
                    pname = pname + eep
                lname = ''
                for eel in el:
                    lname = lname + eel
                name = 'com_'+pname+'_'+lname
                pt = propts + ligpts
                
                if name=='com_O_OS':
                    print pt

            
    return       
            
            
            
            
            
           
        
def element_clasdasdasdaassification(outfile,comp) :            
            
    ecombnr=str(epcount*100+elcount)
    ecombdictkey=str(ep)+'-'+str(el)
                    
        
    if atom1.get_name() in ep and a1_e_serial not in atom1_used:
        atom1_used.append(a1_e_serial)
        x=str(atom1.get_coord()[0])
        y=str(atom1.get_coord()[1])
        z=str(atom1.get_coord()[2])
        outfile.write('0 '+ecombnr+' '+x+' '+y+' '+z+'\n')
        alphaprot.setdefault(ecombdictkey, []).append(x+','+y+','+z)
    if atom2.get_name() in el and a2_e_serial not in atom2_used:
        atom2_used.append(a2_e_serial)
        x=str(atom2.get_coord()[0])
        y=str(atom2.get_coord()[1])
        z=str(atom2.get_coord()[2])
        outfile.write('1 '+ecombnr+' '+x+' '+y+' '+z+'\n')
        alphaprot.setdefault(ecombdictkey, []).append(x+','+y+','+z)
                
    return(alphaprot)

# %% [markdown]
# Calaculates an alpha complex from coordinates for a choosen atomtype and puts them into an dict. Dict key = name of the protein

# %%
def calculate_alpha_complex(BarCollection, name, alphaprot, cwd):
    
    for key,coords in alphaprot.items():
        Bars = []
        tmpoutfile =open(cwd+'/pts_dir/tmp.csv', 'w')
        tmpoutfile.write('x1,x2,x3\n')
        
        for coord in coords:
            tmpoutfile.write(coord+'\n')
        tmpoutfile.close()
        os.system('Rscript PH_Alpha.R '+ cwd+'/pts_dir/tmp.csv '+ cwd+'/pts_dir'+'/tmp.out')
        
        tmpinfile = open(cwd+'/pts_dir/tmp.out')
        lines = tmpinfile.read().splitlines()
        
        for line in lines[1:]:
            a,b,c,d = line.split()
            if d!='Inf':
                if float(d)-float(c) >= 0.01: #If the bar is to small we don't need to use it (more data for nothing)
                    Bars.append([int(b), float(c), float(d)])
        BarCollection[name] = Bars

# %%
def calc_residue_dist(residue1, residue2, outfile, atom1_used, atom2_used, alphaprot) :

    for atom1 in residue1:
        for atom2 in residue2:
            
            distance=atom1-atom2    

            if distance>20:#If the residues is to far from eachother there is no need to calculate the distance for the rest of the atoms
                return(alphaprot)
            if distance >12:#Go to the next atom
                continue
                
            if 'H' not in atom1.get_id() and 'H' not in atom2.get_id(): # DUBBELKOLLA ATT DET INTE FINNS H I ANDRA!!!!
            #if atom1.get_id() != 'H' and atom2.get_id() != 'H':    
                
                a1_serial=str(atom1.serial_number)+atom1.get_name()+atom2.get_name()
                a2_serial=str(atom1.serial_number)+atom1.get_name()+atom2.get_name()
                
                atom_r1=atom1.get_name()
                if 'C' in atom_r1:
                    ele=1
                elif 'H' in atom_r1: #Only used for charged rips calculation
                    ele=5
                    continue
                elif 'O' in atom_r1:
                    ele=3
                elif 'N' in atom_r1:
                    ele=2
                elif 'S' in atom_r1:
                    ele=4
                else:
                    continue
                
                atom_r2=atom2.get_name() 
                if 'C' in atom_r2:
                    ele=1
                elif 'H' in atom_r2: #Only used for charged rips calculation
                    ele=10
                    continue
                elif 'O' in atom_r2:
                    ele=3
                elif 'N' in atom_r2:
                    ele=2
                elif 'S' in atom_r2:
                    ele=4
                elif 'P' in atom_r2:
                    ele=5
                elif 'F' in atom_r2:
                    ele=6
                elif 'Cl' in atom_r2:
                    ele=7
                elif 'Br' in atom_r2:
                    ele=8
                elif 'I' in atom_r2:
                    ele=9
                else:
                    continue
                
                
                
                
                if a1_serial not in atom1_used:
                    atom1_used.append(a1_serial)
                    x=str(atom1.get_coord()[0])
                    y=str(atom1.get_coord()[1])
                    z=str(atom1.get_coord()[2])
                    #outfile.write('0'+' '+'1'+' '+x+' '+y+' '+z+'\n')
                    #alphaprot.setdefault('PROT', []).append(atom1.get_name()+','+atom2.get_name()+','+x+','+y+','+z)
                    alphaprot.setdefault('PROT', []).append([atom1.get_name(),x,y,z])
                    

   
                if a2_serial not in atom2_used:
                    atom2_used.append(a2_serial)
                    x=str(atom2.get_coord()[0])
                    y=str(atom2.get_coord()[1])
                    z=str(atom2.get_coord()[2])
                    #outfile.write('1'+' '+'1'+' '+x+' '+y+' '+z+'\n')
                    #alphaprot.setdefault('LIG', []).append(atom1.get_name()+','+atom2.get_name()+','+x+','+y+','+z)
                    alphaprot.setdefault('LIG', []).append([atom2.get_name(),x,y,z])
                    
    return(alphaprot)




def calc_dist_matrix(chain_one, chain_two,outfile,alphaprot) :
    
    atom1_used=[]
    atom2_used=[]
    for row, residue_one in enumerate(chain_one) :
        for col, residue_two in enumerate(chain_two) :
            
            alphaprot=calc_residue_dist(residue_one, residue_two, outfile, atom1_used, atom2_used, alphaprot)
                                    
    return(alphaprot)

# %%
def main():
    
    
    
    #python DLIQA.py -location_of_dataset -crossvalidation_file -location_of_value_file -PQR(1)
    PQR=0
    sys_args = sys.argv[1:]
    if sys_args[0]:
        pdb_dir=sys_args[0]
        sys_args = sys.argv[1:]
    if sys_args[0]:
        valuefile=sys_args[0] #################################
        sys_args = sys.argv[1:]
    if sys_args[0]:
        valuefile=sys_args[0]
        sys_args = sys.argv[1:]
    
    
    while 'true':
        input1=raw_input("Save or load ")
        if input1.lower()=='-r':
            args='-r'
            break
        elif input1.lower()=='-s':
            args='-s'
            break
        else:
            break
    
    
    cwd = os.getcwd()
    
    
    pdb_dir= cwd+'/models' #'D:\Downloads\CnM-dataset\models'#'/home/joakim/Downloads/models' #str(args[0]) 
    
    

    
    
    
    if not '-r' in args:
    
        pdb_list=[]
        for file in os.listdir(pdb_dir):
            if file.endswith(".pdb"):
                pdb_list.append([pdb_dir,file])
        
        
        valuefile= cwd+'/CnM.featuresNPqDNZ'#'/home/joakim/Downloads/CnM.featuresNPqDNZ'#'D:\Downloads\CnM.featuresNPqDNZ'
        value_df=pandas.read_csv(valuefile,delim_whitespace=1)

        #Just a check to se if the data_set dir exist, in this case it removes it and all the files in it and make a new one
        if os.path.exists(cwd + "/pts_dir"):
            shutil.rmtree(cwd + "/pts_dir")
            os.makedirs(cwd + "/pts_dir")
        else:
            os.makedirs(cwd + "/pts_dir")
        


        
        score=[]
        dist_matrix=[]
        BarCollection = {}
        for counter, filepath_pdb in enumerate(pdb_list):
            name=pdb_list[counter][1][:-11]
            
            working_file=open(cwd + '/pts_dir/working_file.txt', 'a')
            working_file.write(name+'\n') #Writes what pdb have been worked on in working_file.txt
            working_file.close()
            
            print(counter+1)            
            print(name)
            
            filename_pdb=os.path.join(pdb_list[counter][0],pdb_list[counter][1])

            #If PQR=1 it will try to run pdb2pqr
            if PQR==1:
                outfile=filename_pdb[:-3]+'pqr'
                line = '/software/apps/python/2.7.13/anaconda-5.0.0.1/bin/python /proj/wallner/apps/apbs-pdb2pqr/pdb2pqr/pdb2pqr.py --ff=amber '+ filename_pdb +' '+ outfile
                os.system(line)
                filename_pdb=outfile
                
            try: 
                PDBobj = PDBParser()
                structure = PDBobj.get_structure(filename_pdb, filename_pdb)
                model = structure[0]
            
            except IOError: 
                print('IO Error', filename_pdb)      
                while 'true':
                    input1=raw_input("Error parsing PDB file! Continue(y/n)...")
                    if input1.lower()=='y':
                        continue
                    elif input1.lower()=='n':
                        sys.exit()
                
        
            #Finds the score of the file !!!!!!change to an dict
            score.append(value_df.loc[((value_df['#'] == name),'CPscore')].values[0])



            chain_used=[]
            outfile=open(cwd + "/pts_dir/"+name + '.pts', 'w')
            for chain1 in model:
                for chain2 in model:
                    alphaprot={} #Used to make temp file for alpha complex calculations, its a dict of coord for every atomtype used
                    comp={}
                    if chain1!=chain2 and chain2 not in chain_used:
                        chain_used.append(chain1)
                        comp=calc_dist_matrix(chain1, chain2, outfile,comp) #Makes coord files for matlab and returns a dict for alpha complex
                        #element_classification(outfile,comp)
                        #calculate_alpha_complex(BarCollection, name, alphaprot, cwd) #Calculates alpha complex
                        
            outfile.close()
    
    

    if '-s' in args and '-r' in args:
        print('Do not use save(-s) and read(-r) at the same time')
        sys.exit()
    elif '-s' in args:
        print('-Saving files...')
        #np.savez_compressed('score', score)
        #np.savez_compressed('Alpha_Complex', BarCollection)
        print('-Files saved as "dist_matrix.npz","score.npz"')

    elif '-r' in args:
        print('-Loading files...')
        score = np.load('score.npz')
        #dist_matrix = np.load('dist_matrix.npz')
        
        for key,array in score.items():
            score=score[key]
        #for key,array in dist_matrix.items():
            #dist_matrix=dist_matrix[key]
            
        print('-Files loaded')
    
    os.remove(cwd+'/pts_dir/tmp.out')
    os.remove(cwd+'/pts_dir/tmp.csv')
    
   # print(score[1])
   # print(score.shape)
    line = 'matlab -nodisplay -nodesktop -nosplash -r '+cwd+'/bar.m'
    os.system(line)
    
if __name__ == '__main__':
    main()
# Out:
# Save or load -s
# 1
# D1AKJ-a14b
# 90OGCB
# 90OGCG
# 93NCB
# 93NCG
# 94CACB
# 94CACG
# 94CACD
# 94CAOE1
# 95CBCB
# 95CBCG
# 96CG1CB
# 96CG1CG
# 96CG1CD
# 98CN
# 98CCA
# 98CCB
# 98CCG
# 98CCD
# 98COE1
# 98COE2
# 98CC
# 98CO
# 99ON
# 99OCA
# 99OCB
# 99OCG
# 99OCD
# 99OOE1
# 99OOE2
# 99OC
# 99OO
# 102CBCD2
# 102CBCE2
# 102CBCZ
# 103OGCD2
# 103OGCE2
# 103OGCZ
# 102CBCG
# 103OGOG1
# 103OGCG2
# 102CBO
# 103OGC
# 103OGO
# 104CO
# 105OO
# 102CBOD2
# 103OGN
# 103OGCB
# 103OGOD2
# 104CCB
# 104CCG
# 104COD2
# 105ON
# 105OCA
# 105OCB
# 105OCG
# 105OOD2
# 101CACZ
# 102CBNE
# 102CBCZ
# 103OGCZ
# 104CNE
# 104CCZ
# 105ONE
# 105OCZ
# 102CBCE1
# 103OGCE1
# 103OGCZ
# 105OCE1
# 101CACB
# 101CAC
# 102CBCB
# 102CBC
# 102CBO
# 104CCA
# 104CCB
# 104CCG
# 104CCD
# 104CNE
# 104CCZ
# 104CC
# 104CO
# 105OCB
# 105OCG
# 105OCD
# 105OCZ
# 105OC
# 100NC
# 101CAN
# 101CACA
# 101CACB
# 101CACG
# 101CAC
# 101CAO
# 102CBN
# 102CBCA
# 102CBCB
# 102CBCG
# 102CBC
# 102CBO
# 103OGC
# 103OGO
# 104CN
# 104CCA
# 104CCB
# 104CCG
# 104CC
# 104CO
# 105ON
# 105OCA
# 105OCB
# 105OC
# 105OO
# 100NN
# 100NCA
# 100NCB
# 100NCG
# 100NCD
# 100NOE1
# 100NOE2
# 100NC
# 100NO
# 101CAN
# 101CACA
# 101CACB
# 101CACG
# 101CACD
# 101CAOE1
# 101CAOE2
# 101CAC
# 101CAO
# 102CBN
# 102CBCA
# 102CBCB
# 102CBCG
# 102CBCD
# 102CBOE1
# 102CBOE2
# 102CBC
# 102CBO
# 103OGN
# 103OGCA
# 103OGCB
# 103OGCG
# 103OGCD
# 103OGOE1
# 103OGOE2
# 103OGC
# 103OGO
# 104CN
# 104CCA
# 104CCB
# 104CCG
# 104CCD
# 104COE1
# 104COE2
# 104CC
# 104CO
# 105ON
# 105OCA
# 105OCB
# 105OCG
# 105OCD
# 105OOE1
# 105OOE2
# 105OC
# 105OO
# 101CAN
# 101CACA
# 101CACG
# 101CAOD1
# 102CBN
# 102CBCA
# 102CBCB
# 102CBCG
# 102CBOD1
# 102CBND2
# 103OGN
# 103OGCA
# 103OGCG
# 103OGOD1
# 103OGND2
# 104CN
# 104CCA
# 104CCG
# 104COD1
# 104CND2
# 105ON
# 105OCA
# 105OCG
# 105OOD1
# 105OND2
# 115CCD2
# 116OCG
# 116OCD1
# 116OCD2
# 106NCB
# 106NCG
# 106NOD2
# 107CACB
# 107CACG
# 107CAOD1
# 107CAOD2
# 108CBCB
# 108CBCG
# 108CBOD2
# 109CGOD2
# 115CN
# 115CCA
# 115CCB
# 115CCG
# 115COD1
# 115COD2
# 115CO
# 116ON
# 116OCA
# 116OCB
# 116OCG
# 116OOD1
# 116OOD2
# 106NNE
# 106NCZ
# 107CACG
# 107CACD
# 107CANE
# 107CACZ
# 108CBCD
# 108CBNE
# 108CBCZ
# 109CGNE
# 109CGCZ
# 110CDCZ
# 107CACE1
# 107CACZ
# 115CCG
# 115COD1
# 115COD2
# 115CC
# 115CO
# 116OCB
# 116OCG
# 116OOD1
# 116OOD2
# 116OC
# 116OO
# 115CCA
# 115CC
# 115CO
# 116ON
# 116OCA
# 116OCD1
# 116OC
# 116OO
# 106NN
# 106NCA
# 106NCB
# 106NCG
# 106NCD
# 106NNE
# 106NCZ
# 106NC
# 106NO
# 107CAN
# 107CACA
# 107CACB
# 107CACG
# 107CACD
# 107CANE
# 107CACZ
# 107CAC
# 107CAO
# 108CBN
# 108CBCA
# 108CBCB
# 108CBCG
# 108CBCD
# 108CBNE
# 108CBCZ
# 108CBC
# 108CBO
# 109CGCA
# 109CGCB
# 109CGCG
# 109CGCD
# 109CGNE
# 109CGCZ
# 109CGC
# 110CDCB
# 110CDCG
# 110CDCD
# 110CDNE
# 110CDCZ
# 111NECB
# 111NECG
# 111NECD
# 111NENE
# 111NECZ
# 111NEC
# 112CZCB
# 112CZCG
# 115CN
# 115CCA
# 115CCB
# 115CCG
# 115CCD
# 115CNE
# 115CCZ
# 115CC
# 115CO
# 116ON
# 116OCA
# 116OCB
# 116OCG
# 116OCD
# 116ONE
# 116OCZ
# 116OC
# 116OO
# 106NN
# 106NCA
# 106NCB
# 106NCG
# 106NCD
# 106NC
# 106NO
# 107CAN
# 107CACA
# 107CACB
# 107CACG
# 107CACD
# 107CAC
# 107CAO
# 108CBN
# 108CBCA
# 108CBCB
# 108CBCG
# 108CBCD
# 108CBC
# 108CBO
# 109CGN
# 109CGCA
# 109CGCB
# 109CGC
# 110CDN
# 110CDCB
# 110CDC
# 111NEN
# 111NECA
# 111NECB
# 111NECG
# 111NECD
# 111NEC
# 112CZN
# 112CZCB
# 112CZCD
# 115CN
# 115CCA
# 115CCB
# 115CCG
# 115CCD
# 115CNE
# 115CCZ
# 115CC
# 115CO
# 116ON
# 116OCA
# 116OCB
# 116OCG
# 116OCD
# 116ONE
# 116OCZ
# 116OC
# 116OO
# 106NN
# 106NCA
# 106NCB
# 106NCG
# 106NCD
# 106NOE1
# 106NOE2
# 106NC
# 106NO
# 107CAN
# 107CACA
# 107CACB
# 107CACG
# 107CACD
# 107CAOE1
# 107CAOE2
# 107CAC
# 107CAO
# 108CBN
# 108CBCA
# 108CBCB
# 108CBCG
# 108CBCD
# 108CBOE1
# 108CBOE2
# 108CBC
# 108CBO
# 109CGN
# 109CGCA
# 109CGCB
# 109CGCG
# 109CGCD
# 109CGOE1
# 109CGOE2
# 109CGC
# 110CDN
# 110CDCA
# 110CDCB
# 110CDCG
# 110CDCD
# 110CDOE1
# 110CDOE2
# 111NEN
# 111NECA
# 111NECB
# 111NECG
# 111NECD
# 111NEOE1
# 111NEOE2
# 111NEC
# 112CZN
# 112CZCA
# 112CZCB
# 112CZCG
# 112CZCD
# 112CZOE1
# 112CZOE2
# 115CN
# 115CCA
# 115CCB
# 115CCG
# 115CCD
# 115COE1
# 115COE2
# 115CC
# 115CO
# 116ON
# 116OCA
# 116OCB
# 116OCG
# 116OCD
# 116OOE1
# 116OOE2
# 116OC
# 116OO
# 106NN
# 106NCA
# 106NCB
# 106NCG
# 106NOD1
# 106NND2
# 107CAN
# 107CACA
# 107CACB
# 107CACG
# 107CAOD1
# 107CAND2
# 108CBN
# 108CBCA
# 108CBCG
# 108CBOD1
# 108CBND2
# 109CGOD1
# 115CN
# 115CCA
# 115CCB
# 115CCG
# 115COD1
# 115CND2
# 115CC
# 116ON
# 116OCA
# 116OCB
# 116OCG
# 116OOD1
# 116OND2
# 116OC
# 116OO
# 115CN
# 116ON
# 116OCA
# 116OCB
# 116OCG
# 116OOE2
# 116OO
# 119CACD2
# 122CCB
# 122CCG
# 122CCD1
# 122CCD2
# 123OCD2
# 122CN
# 122CCA
# 123ON
# 123OCA
# 117NCD2
# 117NCE2
# 117NCZ
# 118CDCE2
# 119CACD2
# 119CACE1
# 119CACE2
# 119CACZ
# 120CBCG
# 120CBCD2
# 120CBCE1
# 120CBCE2
# 120CBCZ
# 121CGCD2
# 121CGCE2
# 121CGCZ
# 122CCD2
# 122CCE2
# 122CCZ
# 123OCE2
# 120CBCG2
# 121CGCG2
# 119CACD2
# 120CBCD2
# 121CGCD2
# 120CBO
# 121CGC
# 121CGO
# 117NC
# 117NO
# 118CDCA
# 118CDC
# 118CDO
# 119CAC
# 119CAO
# 120CBN
# 120CBCA
# 120CBC
# 120CBO
# 121CGN
# 121CGCA
# 121CGC
# 121CGO
# 122CC
# 122CO
# 123OC
# 123OO
# 117NN
# 117NCA
# 117NCG
# 117NCD1
# 117NC
# 117NO
# 118CDN
# 118CDCA
# 118CDCB
# 118CDCG
# 118CDCD1
# 118CDC
# 118CDO
# 119CAN
# 119CACA
# 119CACB
# 119CACG
# 119CACD1
# 119CAC
# 119CAO
# 120CBN
# 120CBCA
# 120CBCB
# 124NC
# 125CAN
# 125CACA
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OC
# 127OO
# 125CAN
# 125CAO
# 126CN
# 126CO
# 127ON
# 127OO
# 124NCD2
# 124NCE2
# 124NCZ
# 125CACE2
# 124NO
# 124NCD1
# 124NC
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NOD1
# 124NOD2
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CAOD1
# 125CAOD2
# 125CAC
# 125CAO
# 126CCA
# 126CCB
# 126CCG
# 126COD1
# 126COD2
# 126CO
# 127OCB
# 127OCG
# 127OOD1
# 127OOD2
# 124NN
# 124NCB
# 124NNE2
# 124NC
# 124NO
# 125CACA
# 125CACB
# 125CANE2
# 125CAC
# 125CAO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NCD
# 124NNE
# 124NCZ
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CACD
# 125CANE
# 125CACZ
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126CCD
# 126CNE
# 126CCZ
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OCD
# 127ONE
# 127OCZ
# 124NN
# 124NCB
# 124NCG
# 124NCD1
# 124NCD2
# 124NCE1
# 124NCE2
# 124NCZ
# 125CAN
# 125CACB
# 125CACG
# 125CACD1
# 125CACD2
# 125CACE1
# 125CACE2
# 125CACZ
# 126CCD1
# 126CCE1
# 126CCE2
# 126CCZ
# 127OCD1
# 127OCE1
# 127OCZ
# 124NCB
# 124NCG
# 124NCD1
# 124NCD2
# 125CACA
# 125CACB
# 125CACG
# 125CACD1
# 125CACD2
# 125CAC
# 125CAO
# 126CCG
# 126CCD1
# 126CCD2
# 127OCG
# 127OCD1
# 127OCD2
# 124NN
# 124NOG
# 124NC
# 125CAN
# 125CACA
# 125CACB
# 125CAOG
# 125CAC
# 125CAO
# 126COG
# 126CC
# 126CO
# 127OOG
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NOD1
# 124NOD2
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CAOD1
# 125CAOD2
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126COD1
# 126COD2
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OOD1
# 127OOD2
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NCD1
# 124NCD2
# 124NCE1
# 124NCE2
# 124NCZ
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CACD1
# 125CACD2
# 125CACE1
# 125CACE2
# 125CACZ
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126CCD1
# 126CCD2
# 126CCE1
# 126CCE2
# 126CCZ
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OCD1
# 127OCD2
# 127OCE1
# 127OCE2
# 127OCZ
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NCD
# 124NNE
# 124NCZ
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CACD
# 125CANE
# 125CACZ
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126CCD
# 126CNE
# 126CCZ
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OCD
# 127ONE
# 127OCZ
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NCD
# 124NNE
# 124NCZ
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CACD
# 125CANE
# 125CACZ
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126CCD
# 126CNE
# 126CCZ
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OCD
# 127ONE
# 127OCZ
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NCD
# 124NOE1
# 124NOE2
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CACD
# 125CAOE1
# 125CAOE2
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126CCD
# 126COE1
# 126COE2
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OCD
# 127OOE1
# 127OOE2
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NOD1
# 124NND2
# 124NC
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CAOD1
# 125CAND2
# 125CAC
# 125CAO
# 126CN
# 126CCA
# 126CCB
# 126CCG
# 126COD1
# 126CND2
# 126CC
# 126CO
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OOD1
# 127OND2
# 127OC
# 127OO
# 124NN
# 124NCA
# 124NCB
# 124NCG
# 124NOE2
# 124NO
# 125CAN
# 125CACA
# 125CACB
# 125CACG
# 125CAOE2
# 126CN
# 126CCA
# 126CCG
# 126COE2
# 127ON
# 127OCA
# 127OCB
# 127OCG
# 127OCD
# 127OOE2
# 127OCG
# 127OCD1
# 127OCD2
# 128NCA
# 128NCB
# 128NCG
# 128NCD1
# 128NCD2
# 128NC
# 129CACA
# 129CACB
# 129CACG
# 129CACD1
# 129CACD2
# 129CAC
# 130CBCB
# 130CBCG
# 130CBCD1
# 130CBCD2
# 131CGCD1
# 131CGCD2
# 137CCA
# 137CCB
# 137CCG
# 137CCD1
# 137CCD2
# 137CC
# 138OCB
# 138OCG
# 138OCD1
# 138OCD2
# 128NN
# 128NCA
# 129CAN
# 129CACA
# 137CN
# 137CCA
# 128NCB
# 128NCG
# 128NOD1
# 128NOD2
# 129CACB
# 129CACG
# 129CAOD1
# 129CAOD2
# 130CBCG
# 130CBOD2
# 131CGCB
# 131CGCG
# 131CGOD1
# 131CGOD2
# 132CDCB
# 132CDCG
# 132CDOD1
# 132CDOD2
# 133NECA
# 133NECB
# 133NECG
# 133NEOD1
# 133NEOD2
# 134CZN
# 134CZCA
# 134CZCB
# 134CZCG
# 134CZOD1
# 134CZOD2
# 134CZC
# 134CZO
# 137COD2
# 138OOD2
# 133NENE2
# 134CZCB
# 134CZCD
# 134CZNE2
# 128NCA
# 128NCB
# 128NCG
# 128NCD
# 128NNE
# 128NCZ
# 129CACB
# 129CACG
# 129CACD
# 129CANE
# 129CACZ
# 130CBCG
# 130CBCD
# 130CBNE
# 130CBCZ
# 131CGCB
# 131CGCG
# 131CGCD
# 131CGNE
# 131CGCZ
# 132CDCG
# 132CDCD
# 132CDNE
# 132CDCZ
# 133NECB
# 133NECG
# 133NECD
# 133NENE
# 133NECZ
# 134CZN
# 134CZCA
# 134CZCB
# 134CZCG
# 134CZCD
# 134CZNE
# 134CZCZ
# 137CCG
# 137CCD
# 137CNE
# 137CCZ
# 138OCD
# 138ONE
# 138OCZ
# 128NCE1
# 128NCZ
# 134CZCD1
# 134CZCE1
# 134CZCZ
# 128NCD1
# 128NN
# 128NCA
# 128NCB
# 128NCG
# 128NOD1
# 128NOD2
# 128NC
# 128NO
# 129CACA
# 129CACB
# 129CACG
# 129CAOD1
# 129CAOD2
# 129CAC
# 129CAO
# 130CBCB
# 130CBCG
# 130CBOD1
# 130CBOD2
# 130CBC
# 130CBO
# 131CGCA
# 131CGCB
# 131CGCG
# 131CGOD1
# 131CGOD2
# 131CGC
# 131CGO
# 132CDCB
# 132CDCG
# 132CDOD1
# 132CDOD2
# 132CDO
# 133NECB
# 133NECG
# 133NEOD1
# 133NEOD2
# 133NEO
# 134CZCA
# 134CZCB
# 134CZCG
# 134CZOD1
# 134CZOD2
# 134CZC
# 134CZO
# 137CCB
# 137CCG
# 137COD1
# 137COD2
# 137CC
# 137CO
# 138OCG
# 138OOD1
# 138OOD2
# 138OO
# 128NN
# 128NCA
# 128NCB
# 128NCG
# 128NCD1
# 128NCD2
# 128NC
# 128NO
# 129CAN
# 129CACA
# 129CAC
# 129CAO
# 130CBC
# 130CBO
# 131CGC
# 131CGO
# 134CZC
# 134CZO
# 137CN
# 137CCA
# 137CC
# 137CO
# 138OC
# 138OO
# 128NN
# 128NCA
# 128NCB
# 128NCG
# 128NCD
# 128NNE
# 128NCZ
# 128NC
# 128NO
# 129CAN
# 129CACA
# 129CACB
# 129CACG
# 129CACD
# 129CANE
# 129CACZ
# 129CAC
# 129CAO
# 130CBN
# 130CBCA
# 130CBCB
# 130CBCG
# 130CBCD
# 130CBNE
# 130CBCZ
# 130CBC
# 130CBO
# 131CGN
# 131CGCA
# 131CGCB
# 131CGCG
# 131CGCD
# 131CGNE
# 131CGCZ
# 131CGC
# 131CGO
# 132CDN
# 132CDCA
# 132CDCB
# 132CDCG
# 132CDCD
# 132CDNE
# 132CDCZ
# 132CDC
# 133NEN
# 133NECA
# 133NECB
# 133NECG
# 133NECD
# 133NENE
# 133NECZ
# 133NEC
# 134CZN
# 134CZCA
# 134CZCB
# 134CZCG
# 134CZCD
# 134CZNE
# 134CZCZ
# 134CZC
# 134CZO
# 137CN
# 137CCA
# 137CCB
# 137CCG
# 137CCD
# 137CNE
# 137CCZ
# 137CC
# 137CO
# 138ON
# 138OCA
# 138OCB
# 138OCG
# 138OCD
# 138ONE
# 138OCZ
# 138OC
# 138OO
# 128NN
# 128NCA
# 128NCB
# 128NCG
# 128NCD
# 128NNE
# 128NCZ
# 128NC
# 128NO
# 129CAN
# 129CACA
# 129CACB
# 129CACG
# 129CACD
# 129CANE
# 129CACZ
# 129CAC
# 129CAO
# 130CBN
# 130CBCA
# 130CBCB
# 130CBCG
# 130CBCD
# 130CBNE
# 130CBCZ
# 130CBC
# 130CBO
# 131CGN
# 131CGCA
# 131CGCB
# 131CGC
# 132CDN
# 133NEN
# 134CZN
# 134CZCA
# 134CZCB
# 134CZC
# 137CN
# 137CCA
# 137CCB
# 137CCG
# 137CCD
# 137CNE
# 137CCZ
# 137CC
# 137CO
# 138ON
# 138OCA
# 138OCB
# 138OCG
# 138OCD
# 138ONE
# 138OCZ
# 138OC
# 138OO
# 128NN
# 128NCA
# 128NCB
# 128NCG
# 128NCD
# 128NOE1
# 128NOE2
# 128NC
# 128NO
# 129CAN
# 129CACA
# 129CACB
# 129CACG
# 129CACD
# 129CAOE1
# 129CAOE2
# 129CAC
# 129CAO
# 130CBN
# 130CBCA
# 130CBCB
# 130CBCG
# 130CBCD
# 130CBOE1
# 130CBOE2
# 130CBC
# 131CGN
# 131CGCA
# 131CGCB
# 131CGCG
# 131CGCD
# 131CGOE1
# 131CGOE2
# 132CDN
# 132CDCB
# 132CDCG
# 132CDCD
# 132CDOE1
# 132CDOE2
# 133NEN
# 133NECA
# 133NECB
# 133NECG
# 133NECD
# 133NEOE1
# 133NEOE2
# 134CZN
# 134CZCA
# 134CZCB
# 134CZCG
# 134CZCD
# 134CZOE1
# 134CZOE2
# 134CZC
# 134CZO
# 137CN
# 137CCA
# 137CCB
# 137CCG
# 137CCD
# 137COE1
# 137COE2
# 137CC
# 137CO
# 138ON
# 138OCA
# 138OCB
# 138OCG
# 138OCD
# 138OOE1
# 138OOE2
# 138OC
# 138OO
# 128NN
# 128NCA
# 128NCB
# 128NCG
# 128NOD1
# 128NND2
# 128NC
# 129CAN
# 129CACA
# 129CACB
# 129CACG
# 129CAOD1
# 129CAND2
# 130CBN
# 130CBCG
# 130CBOD1
# 130CBND2
# 131CGCG
# 131CGOD1
# 131CGND2
# 132CDOD1
# 133NECG
# 133NEOD1
# 133NEND2
# 134CZN
# 134CZCB
# 134CZCG
# 134CZOD1
# 134CZND2
# 137CN
# 137CCA
# 137CCB
# 137CCG
# 137COD1
# 137CND2
# 138ON
# 138OCA
# 138OCB
# 138OCG
# 138OOD1
# 138OND2
# 128NN
# 142OC
# 142OO
# 139NN
# 139NCA
# 139NCB
# 139NCG
# 139NCD1
# 139NCD2
# 139NC
# 139NO
# 140CAN
# 140CACA
# 140CACB
# 140CACG
# 140CACD1
# 140CACD2
# 140CAC
# 140CAO
# 141CN
# 141CCA
# 141CCB
# 141CCG
# 141CCD1
# 141CCD2
# 141CC
# 141CO
# 142ON
# 142OCA
# 142OCB
# 142OCG
# 142OCD1
# 142OCD2
# 142OC
# 142OO
# 139NN
# 139NCA
# 140CAN
# 140CACA
# 141CN
# 141CCA
# 142ON
# 142OCA
# 139NOD2
# 139NCG
# 139NCD
# 139NNE
# 139NCZ
# 140CACD
# 140CANE
# 140CACZ
# 141CCD
# 141CNE
# 141CCZ
# 142OCD
# 142ONE
# 142OCZ
# 139NCA
# 139NCB
# 139NCG
# 139NOD1
# 139NOD2
# 139NC
# 139NO
# 140CACB
# 140CACG
# 140CAOD1
# 140CAOD2
# 140CAC
# 140CAO
# 141CCG
# 141COD1
# 141COD2
# 141CC
# 141CO
# 142OCB
# 142OCG
# 142OOD1
# 142OOD2
# 142OC
# 142OO
# 139NN
# 139NCA
# 139NCB
# 139NCG
# 139NCD1
# 139NCD2
# 139NCE2
# 139NCZ
# 139NC
# 139NO
# 140CAN
# 140CACA
# 140CACB
# 140CACG
# 140CACD1
# 140CACD2
# 140CACE2
# 140CACZ
# 140CAC
# 140CAO
# 141CN
# 141CCA
# 141CCB
# 141CCG
# 141CCD1
# 141CCD2
# 141CCE1
# 141CCE2
# 141CCZ
# 141CC
# 141CO
# 142ON
# 142OCA
# 142OCB
# 142OCG
# 142OCD1
# 142OCD2
# 142OCE1
# 142OCE2
# 142OCZ
# 142OC
# 142OO
# 139NN
# 139NCA
# 139NCB
# 139NCG
# 139NCD
# 139NNE
# 139NCZ
# 139NC
# 139NO
# 140CAN
# 140CACA
# 140CACB
# 140CACG
# 140CACD
# 140CANE
# 140CACZ
# 140CAC
# 140CAO
# 141CN
# 141CCA
# 141CCB
# 141CCG
# 141CCD
# 141CNE
# 141CCZ
# 141CC
# 141CO
# 142ON
# 142OCA
# 142OCB
# 142OCG
# 142OCD
# 142ONE
# 142OCZ
# 142OC
# 142OO
# 139NN
# 139NCA
# 139NCB
# 139NCG
# 139NCD
# 139NNE
# 139NCZ
# 139NC
# 139NO
# 140CAN
# 140CACA
# 140CACB
# 140CACG
# 140CACD
# 140CANE
# 140CACZ
# 140CAC
# 140CAO
# 141CN
# 141CCA
# 141CCB
# 141CCG
# 141CCD
# 141CNE
# 141CCZ
# 141CC
# 141CO
# 142ON
# 142OCA
# 142OCB
# 142OCG
# 142OCD
# 142ONE
# 142OCZ
# 142OC
# 142OO
# 139NN
# 139NCA
# 139NCB
# 139NCG
# 139NCD
# 139NOE1
# 139NOE2
# 139NC
# 139NO
# 140CAN
# 140CACA
# 140CACB
# 140CACG
# 140CACD
# 140CAOE1
# 140CAOE2
# 140CAC
# 140CAO
# 141CN
# 141CCA
# 141CCB
# 141CCG
# 141CCD
# 141COE1
# 141COE2
# 141CC
# 141CO
# 142ON
# 142OCA
# 142OCB
# 142OCG
# 611CDOE1
# 611CDOE2
# 611CDC
# 611CDO
# 612NEN
# 612NECA
# 612NECB
# 612NECG
# 612NECD
# 612NEOE1
# 612NEOE2
# 612NEC
# 612NEO
# 613CZN
# 613CZCA
# 613CZCB
# 613CZCG
# 613CZCD
# 613CZOE1
# 613CZOE2
# 613CZC
# 613CZO
# 616CN
# 616CCA
# 616CCB
# 616CCG
# 616CCD
# 616COE1
# 616CC
# 616CO
# 617ON
# 617OCA
# 617OCB
# 617OCG
# 617OCD
# 617OOE1
# 617OOE2
# 617OC
# 617OO
# 609CBN
# 610CGN
# 610CGCA
# 610CGC
# 611CDN
# 611CDCA
# 611CDC
# 612NEN
# 612NECA
# 612NECB
# 612NECG
# 612NEOD1
# 612NEC
# 612NEO
# 613CZN
# 613CZCA
# 613CZCB
# 613CZCG
# 613CZOD1
# 613CZC
# 613CZO
# 616CN
# 617ON
# 617OCA
# 617OC
# 609CBOE2
# 609CBO
# 610CGN
# 610CGCA
# 610CGCB
# 610CGCG
# 610CGCD
# 610CGOE1
# 610CGOE2
# 610CGC
# 610CGO
# 611CDN
# 611CDCA
# 611CDCB
# 611CDCG
# 611CDCD
# 611CDOE1
# 611CDOE2
# 611CDC
# 611CDO
# 612NEN
# 612NECA
# 612NECB
# 612NECG
# 612NECD
# 612NEOE1
# 612NEOE2
# 612NEC
# 612NEO
# 613CZN
# 613CZCA
# 613CZCB
# 613CZCG
# 613CZCD
# 613CZOE1
# 613CZOE2
# 613CZC
# 613CZO
# 616CCB
# 616CO
# 617ON
# 617OCA
# 617OCB
# 617OOE2
# 617OC
# 617OO
# 612NEN
# 613CZN
# 613CZCA
# 611CDCD2
# 612NECB
# 612NECG
# 612NECD2
# 613CZN
# 613CZCA
# 613CZCB
# 613CZCG
# 613CZCD1
# 613CZCD2
# 619CACE2
# 619CACZ
# 623CCE2
# 623CCZ
# 624OCD2
# 624OCE2
# 624OCZ
# 621CG1C
# 624OCA
# 624OCG
# 624OC
# 618NN
# 618NCD
# 618NCA
# 618NCB
# 618NCG
# 618NC
# 619CAN
# 619CACD
# 619CACA
# 619CACB
# 619CACG
# 619CAC
# 619CAO
# 620CBN
# 620CBCD
# 620CBCA
# 620CBCB
# 620CBCG
# 620CBC
# 620CBO
# 621CG1N
# 621CG1CD
# 621CG1CA
# 621CG1CB
# 621CG1CG
# 621CG1C
# 621CG1O
# 622CG2N
# 622CG2CD
# 622CG2CA
# 622CG2CB
# 622CG2CG
# 622CG2C
# 622CG2O
# 623CN
# 623CCD
# 623CCA
# 623CCB
# 623CCG
# 623CC
# 623CO
# 624ON
# 624OCD
# 624OCA
# 624OCB
# 624OCG
# 624OC
# 624OO
# 618NN
# 618NCA
# 618NCB
# 618NCG
# 619CAN
# 619CACA
# 619CACB
# 619CACG
# 619CACD
# 619CANE
# 619CACZ
# 619CAC
# 620CBN
# 620CBCA
# 620CBCB
# 620CBCG
# 620CBCD
# 620CBNE
# 620CBCZ
# 620CBC
# 621CG1N
# 621CG1CA
# 621CG1CB
# 622CG2CB
# 622CG2OE2
# 622CG2O
# 623CO
# 624OO
# 622CG2CE1
# 621CG1CE2
# 624OCD2
# 624OCE2
# 625NCD
# 625NCA
# 625NCB
# 625NCG
# 626CACD
# 626CACB
# 626CACG
# 627CBCG
# 631CCD
# 631CCA
# 631CCB
# 631CCG
# 632ON
# 632OCD
# 632OCA
# 632OCB
# 632OCG
# 625NN
# 625NCB
# 632OO
# 625NC
# 625NO
# 626CAC
# 626CAO
# 627CBO
# 628CGO
# 629OD1C
# 629OD1O
# 631CC
# 631CO
# 632OC
# 632OO
# 625NN
# 625NCA
# 625NCB
# 625NC
# 625NO
# 626CAN
# 626CACA
# 626CACB
# 626CAC
# 626CAO
# 627CBN
# 627CBCA
# 627CBCB
# 627CBC
# 627CBO
# 628CGN
# 628CGCA
# 628CGCB
# 628CGC
# 628CGO
# 629OD1N
# 629OD1CA
# 629OD1CB
# 629OD1C
# 629OD1O
# 630OD2CA
# 630OD2CB
# 630OD2C
# 630OD2O
# 631CN
# 631CCA
# 631CCB
# 631CC
# 631CO
# 632ON
# 632OCA
# 632OCB
# 632OC
# 632OO
# 625NN
# 625NCA
# 625NCB
# 625NC
# 626CAN
# 626CACA
# 626CACB
# 626CAC
# 626CAO
# 627CBN
# 627CBCA
# 627CBCB
# 628CGN
# 628CGCA
# 628CGCB
# 629OD1N
# 629OD1CA
# 629OD1CB
# 631CN
# 631CCA
# 631CCB
# 631CC
# 631CO
# 632ON
# 632OCA
# 632OCB
# 632OC
# 632OO
# 625NN
# 626CAN
# 631CN
# 631CO
# 632ON
# 632OCA
# 632OCB
# 632OOG
# 632OC
# 632OO
# 625NCA
# 625NCB
# 631CCB
# 631CO
# 632OCB
# 632OCD2
# 632ONE2
# 632OCE2
# 634CACE2
# 634CACZ
# 635CBCE2
# 635CBCZ
# 639CCD2
# 639CCE1
# 639CCE2
# 639CCZ
# 640OCG
# 640OCD2
# 640OCE1
# 640OCE2
# 640OCZ
# 640OO
# 639CCA
# 639CC
# 640OCA
# 640OC
# 633NCD
# 633NCA
# 633NCB
# 633NCG
# 634CAN
# 634CACD
# 634CACA
# 634CACB
# 634CACG
# 635CBCD
# 635CBCA
# 635CBCB
# 635CBCG
# 636CGCB
# 636CGCG
# 639CN
# 639CCD
# 639CCA
# 639CCB
# 639CCG
# 639CC
# 640ON
# 640OCD
# 640OCA
# 640OCB
# 640OCG
# 640OC
# 639CO
# 640OO
# 633NO
# 639CC
# 639CO
# 640OC
# 640OO
# 633NN
# 633NCA
# 633NCB
# 633NC
# 633NO
# 634CAN
# 634CACA
# 634CACB
# 634CAC
# 634CAO
# 635CBCA
# 635CBCB
# 635CBC
# 635CBO
# 636CGC
# 636CGO
# 638CD2O
# 639CN
# 639CCA
# 639CCB
# 639CC
# 639CO
# 640ON
# 640OCA
# 640OCB
# 640OC
# 640OO
# 633NN
# 633NCA
# 633NCB
# 633NC
# 634CAN
# 634CACA
# 634CACB
# 634CAC
# 634CAO
# 635CBN
# 635CBCA
# 635CBCB
# 636CGCB
# 638CD2CB
# 639CN
# 639CCA
# 639CCB
# 639CC
# 639CO
# 640ON
# 640OCA
# 640OCB
# 640OC
# 640OO
# 633NN
# 634CAN
# 634CAO
# 639CN
# 639CCA
# 639CCB
# 639COG
# 639CC
# 639CO
# 640ON
# 640OCA
# 640OCB
# 640OOG
# 640OC
# 640OO
# 634CAOG1
# 635CBOG1
# 639CCB
# 639COG1
# 639CCG2
# 640ON
# 640OCA
# 640OCB
# 640OOG1
# 640OCG2
# 635CBC
# 635CBO
# 637CD1CB
# 637CD1CG
# 637CD1C
# 637CD1O
# 639CC
# 639CO
# 633NCA
# 633NCB
# 633NCG
# 633NC
# 633NO
# 634CAN
# 634CACA
# 634CACB
# 634CACG
# 634CACD
# 634CAC
# 634CAO
# 635CBN
# 635CBCA
# 635CBCB
# 635CBCG
# 635CBCD
# 635CBOE1
# 635CBOE2
# 635CBC
# 635CBO
# 636CGN
# 636CGCA
# 636CGCB
# 636CGCG
# 636CGCD
# 636CGOE1
# 636CGOE2
# 636CGC
# 636CGO
# 637CD1N
# 637CD1CA
# 637CD1CB
# 637CD1CG
# 637CD1CD
# 637CD1OE1
# 637CD1OE2
# 637CD1C
# 637CD1O
# 638CD2N
# 638CD2CA
# 638CD2CB
# 638CD2CG
# 638CD2CD
# 638CD2OE1
# 638CD2OE2
# 638CD2C
# 638CD2O
# 639CN
# 639CCA
# 639CCB
# 639CCG
# 639CCD
# 639COE1
# 639COE2
# 639CC
# 639CO
# 640ON
# 640OCA
# 640OCB
# 640OCG
# 640OCD
# 640OC
# 640OO
# 635CBN
# 637CD1N
# 639CN
# 640ON
# 639CO
# 640OO
# 640ON
# 641NCG
# 641NCD1
# 641NCD2
# 641NCE1
# 641NCE2
# 641NCZ
# 641NO
# 642CACA
# 642CACB
# 642CACG
# 642CACD1
# 642CACD2
# 642CACE1
# 642CACE2
# 642CACZ
# 642CAC
# 642CAO
# 643CCA
# 643CCB
# 643CCG
# 643CCD1
# 643CCD2
# 643CCE1
# 643CCE2
# 643CCZ
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OCG
# 644OCD1
# 644OCD2
# 644OCE1
# 644OCE2
# 644OCZ
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCG
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CACB
# 642CACG
# 642CACD
# 642CANE2
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CCG
# 643CCD
# 643COE1
# 643CNE2
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OCG
# 644OCD
# 644OOE1
# 644ONE2
# 644OC
# 644OO
# 641NN
# 641NCD
# 641NCA
# 641NCB
# 641NCG
# 641NC
# 641NO
# 642CAN
# 642CACD
# 642CACA
# 642CACB
# 642CACG
# 642CAC
# 642CAO
# 643CN
# 643CCD
# 643CCA
# 643CCB
# 643CCG
# 643CC
# 643CO
# 644ON
# 644OCD
# 644OCA
# 644OCB
# 644OCG
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NCG
# 641NC
# 642CAN
# 642CACA
# 642CACB
# 642CACG
# 642CACD
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CCG
# 643CCD
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OCG
# 644OCD
# 644OC
# 644OO
# 641NN
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OC
# 644OO
# 641NCA
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CACB
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CACB
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NOG
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CACB
# 642CAOG
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643COG
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OOG
# 644OC
# 644OO
# 642CAN
# 642CACD
# 642CACA
# 642CAC
# 642CAO
# 643CN
# 643CCD
# 643CCA
# 643CCB
# 643CCG
# 643CC
# 643CO
# 644ON
# 644OCD
# 644OCA
# 644OCB
# 644OCG
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NOG1
# 641NCG2
# 642CAN
# 642CACA
# 642CACB
# 642CAOG1
# 642CACG2
# 642CAC
# 643CN
# 643CCA
# 643CCB
# 643COG1
# 643CCG2
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OOG1
# 644OCG2
# 644OC
# 644OO
# 644OCD2
# 641NC
# 641NO
# 642CACA
# 642CACG
# 642CAC
# 642CAO
# 643CC
# 643CO
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NCG
# 641NCD
# 641NOE1
# 641NOE2
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CACB
# 642CACG
# 642CACD
# 642CAOE1
# 642CAOE2
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CCG
# 643CCD
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OCB
# 644OCG
# 644OCD
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NC
# 642CAN
# 642CACA
# 642CACB
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CC
# 644ON
# 644OCA
# 644OC
# 644OO
# 641NN
# 641NCA
# 641NCB
# 641NC
# 641NO
# 642CAN
# 642CACA
# 642CACB
# 642CAC
# 642CAO
# 643CN
# 643CCA
# 643CCB
# 643CC
# 643CO
# 644ON
# 644OCA
# 644OC
# 644OO
# 642CAN
# 642CACA
# 643CN
# 643CCA
# 644ON
# 644OCA
# 644ON
# 644OO
# 643CN
# 643COG
# 644ON
# 644OCA
# 644OCB
# 644OOG
# 643CO
# 644OCB
# 644OC
# 644OO
# 643CO
# 644OC
# 644OO
# 643CCA
# 643CCD2
# 643CNE2
# 644ON
# 644OCA
# 644OCB
# 644OCG
# 644OCD2
# 644ONE2
# 644OC
# 642CACD2
# 642CACE2
# 642CACZ
# 643CCG
# 643CCD2
# 643CCE1
# 643CCE2
# 643CCZ
# 644ON
# 644OCG
# 644OCD1
# 644OCD2
# 644OCE1
# 644OCE2
# 644OCZ
# 645NCG
# 645NCD1
# 645NCD2
# 645NCE1
# 645NCE2
# 645NCZ
# 645NC
# 645NO
# 646CACG
# 646CACD2
# 646CACE1
# 646CACE2
# 646CACZ
# 646CAC
# 646CAO
# 647CBCE2
# 647CBCZ
# 648OG1CD2
# 648OG1CE2
# 648OG1CZ
# 650CCD2
# 650CCE2
# 650CCZ
# 650CC
# 650CO
# 651OCG
# 651OCD2
# 651OCE2
# 651OCZ
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NCG
# 645NCD
# 645NNE2
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CACB
# 646CACG
# 646CACD
# 646CAOE1
# 646CANE2
# 646CAC
# 646CAO
# 647CBCA
# 647CBCB
# 647CBCG
# 647CBCD
# 647CBNE2
# 647CBC
# 647CBO
# 648OG1CA
# 648OG1CB
# 648OG1CG
# 648OG1CD
# 648OG1OE1
# 648OG1NE2
# 648OG1C
# 648OG1O
# 649CG2CA
# 649CG2CG
# 649CG2CD
# 649CG2NE2
# 649CG2C
# 650CN
# 650CCA
# 650CCB
# 650CCG
# 650CCD
# 650CNE2
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OCG
# 651OCD
# 651OOE1
# 651ONE2
# 651OC
# 651OO
# 645NN
# 645NCD
# 645NCA
# 645NCB
# 645NCG
# 645NC
# 645NO
# 646CAN
# 646CACD
# 646CACA
# 646CACB
# 646CACG
# 646CAC
# 646CAO
# 647CBN
# 647CBCD
# 647CBCA
# 647CBCB
# 647CBCG
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CD
# 648OG1CA
# 648OG1CB
# 648OG1CG
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CD
# 649CG2CA
# 649CG2CB
# 649CG2CG
# 649CG2C
# 650CN
# 650CCD
# 650CCA
# 650CCB
# 650CCG
# 650CC
# 650CO
# 651ON
# 651OCD
# 651OCA
# 651OCB
# 651OCG
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NCG
# 645NCD
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CACB
# 646CACG
# 646CACD
# 646CAC
# 646CAO
# 647CBN
# 647CBCA
# 647CBCB
# 647CBCG
# 647CBCD
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1CG
# 648OG1CD
# 648OG1NE
# 648OG1CZ
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2CG
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650CCG
# 650CC
# 651ON
# 651OCA
# 651OCB
# 651OCG
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CAC
# 646CAO
# 647CBN
# 647CBCA
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CACB
# 646CAC
# 646CAO
# 647CBN
# 647CBCA
# 647CBCB
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CACB
# 646CAC
# 646CAO
# 647CBN
# 647CBCA
# 647CBCB
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CACB
# 646CAC
# 646CAO
# 647CBN
# 647CBCA
# 647CBCB
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NOG
# 645NC
# 645NO
# 646CAN
# 646CACA
# 646CACB
# 646CAOG
# 646CAC
# 646CAO
# 647CBN
# 647CBCA
# 647CBCB
# 647CBOG
# 647CBC
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1OG
# 648OG1C
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2OG
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650COG
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OOG
# 651OC
# 651OO
# 645NN
# 645NCD
# 645NCA
# 645NC
# 645NO
# 646CAN
# 646CACD
# 646CACA
# 646CACB
# 646CACG
# 646CAC
# 646CAO
# 647CBN
# 647CBCD
# 647CBCA
# 648OG1N
# 648OG1CD
# 648OG1CA
# 649CG2N
# 649CG2CD
# 649CG2CA
# 650CN
# 650CCD
# 650CCA
# 650CCB
# 650CCG
# 650CC
# 650CO
# 651ON
# 651OCD
# 651OCA
# 651OCB
# 651OCG
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NOG1
# 645NCG2
# 646CAN
# 646CACA
# 646CACB
# 646CAOG1
# 646CACG2
# 647CBN
# 647CBCB
# 647CBOG1
# 648OG1CB
# 648OG1OG1
# 649CG2OG1
# 650CN
# 650CCA
# 650CCB
# 650COG1
# 650CCG2
# 651ON
# 651OCA
# 651OCB
# 651OOG1
# 651OCG2
# 651OC
# 645NCA
# 645NCB
# 645NCG
# 645NC
# 645NO
# 646CACB
# 646CAO
# 648OG1O
# 650CO
# 645NC
# 645NO
# 646CAO
# 648OG1O
# 645NN
# 645NOG
# 646CAN
# 646CACA
# 646CACB
# 646CAOG
# 647CBN
# 647CBOG
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2OG
# 650CN
# 650CCA
# 650CCB
# 650COG
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OOG
# 651OC
# 651OO
# 651ON
# 648OG1NE
# 648OG1O
# 646CACE1
# 646CACZ
# 647CBCD1
# 647CBCE1
# 647CBCE2
# 647CBCZ
# 648OG1CG
# 648OG1CD1
# 648OG1CE1
# 648OG1CD2
# 648OG1CE2
# 648OG1CZ
# 649CG2CG
# 649CG2CD1
# 649CG2CE1
# 649CG2CD2
# 649CG2CE2
# 649CG2CZ
# 651OCD2
# 646CAO
# 649CG2O
# 650CCB
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OC
# 651OO
# 645NO
# 646CAC
# 646CAO
# 647CBC
# 647CBO
# 648OG1O
# 649CG2CA
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OOG
# 651OC
# 651OO
# 645NN
# 645NCA
# 645NCB
# 645NCG
# 645NCD2
# 645NNE2
# 646CAN
# 646CACA
# 646CACB
# 646CACG
# 646CAND1
# 646CACD2
# 646CANE2
# 646CACE1
# 646CAC
# 647CBN
# 647CBCA
# 647CBCB
# 647CBCG
# 647CBND1
# 647CBCD2
# 647CBNE2
# 647CBCE1
# 647CBC
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1CG
# 648OG1CD2
# 648OG1NE2
# 648OG1C
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2CG
# 649CG2ND1
# 649CG2CD2
# 649CG2NE2
# 649CG2CE1
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650CCG
# 650CND1
# 650CCD2
# 650CNE2
# 650CCE1
# 650CC
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OCG
# 651OND1
# 651OCD2
# 651ONE2
# 651OCE1
# 651OC
# 651OO
# 645NN
# 645NCB
# 645NCG
# 645NCD1
# 645NCD2
# 645NCE1
# 645NCE2
# 645NCZ
# 646CAN
# 646CACA
# 646CACB
# 646CACG
# 646CACD1
# 646CACD2
# 646CACE1
# 646CACE2
# 646CACZ
# 647CBN
# 647CBCA
# 647CBCB
# 647CBCG
# 647CBCD1
# 647CBCD2
# 647CBCE1
# 647CBCE2
# 647CBCZ
# 647CBO
# 648OG1N
# 648OG1CA
# 648OG1CB
# 648OG1CG
# 648OG1CD1
# 648OG1CD2
# 648OG1CE1
# 648OG1CE2
# 648OG1CZ
# 648OG1O
# 649CG2N
# 649CG2CA
# 649CG2CB
# 649CG2CG
# 649CG2CD1
# 649CG2CD2
# 649CG2CE1
# 649CG2CE2
# 649CG2CZ
# 649CG2C
# 649CG2O
# 650CN
# 650CCA
# 650CCB
# 650CCG
# 650CCD1
# 650CCD2
# 650CCE1
# 650CCE2
# 650CCZ
# 650CO
# 651ON
# 651OCA
# 651OCB
# 651OCG
# 651OCD1
# 651OCD2
# 651OCE1
# 651OCE2
# 651OCZ
# 651OC
# 651OO
# 652NCD2
# 652NCE2
# 658CCD2
# 658CCE2
# 658CO
# 659OCD2
# 659OCE2
# 659OO
# 652NCA
# 652NCG
# 652NNE2
# 652NC
# 658CCA
# 658CCG
# 659OCG
# 652NN
# 652NCD
# 652NCA
# 652NCB
# 652NCG
# 652NC
# 653CAN
# 653CACD
# 653CACB
# 653CACG
# 654CBCD
# 654CBCG
# 655CGCG
# 657CD2CG
# 658CN
# 658CCD
# 658CCA
# 658CCB
# 658CCG
# 659ON
# 659OCD
# 659OCB
# 659OCG
# 652NN
# 652NCB
# 652NN
# 652NCA
# 652NC
# 652NO
# 653CAO
# 657CD2O
# 658CO
# 659OO
# 652NN
# 652NCA
# 652NC
# 652NO
# 653CAC
# 653CAO
# 657CD2C
# 657CD2O
# 658CC
# 652NN
# 652NCA
# 652NCB
# 652NC
# 652NO
# 653CAN
# 653CACA
# 653CACB
# 653CAC
# 653CAO
# 654CBN
# 654CBCA
# 654CBCB
# 654CBC
# 654CBO
# 655CGN
# 655CGCA
# 655CGCB
# 655CGC
# 655CGO
# 656CD1CA
# 656CD1C
# 656CD1O
# 657CD2N
# 657CD2CA
# 657CD2CB
# 657CD2C
# 657CD2O
# 658CN
# 658CCA
# 658CCB
# 658CC
# 658CO
# 659ON
# 659OCA
# 659OCB
# 659OC
# 659OO
# 652NN
# 652NCA
# 652NCB
# 652NC
# 652NO
# 653CAN
# 653CACA
# 653CACB
# 653CAC
# 653CAO
# 654CBN
# 654CBCA
# 654CBCB
# 654CBC
# 654CBO
# 655CGN
# 655CGCA
# 655CGCB
# 655CGC
# 655CGO
# 656CD1N
# 656CD1CA
# 656CD1CB
# 656CD1C
# 657CD2N
# 657CD2CA
# 657CD2CB
# 657CD2C
# 657CD2O
# 658CN
# 658CCA
# 658CCB
# 658CC
# 658CO
# 659ON
# 659OCA
# 659OCB
# 659OC
# 659OO
# 652NN
# 652NCA
# 652NCB
# 652NOG
# 652NC
# 652NO
# 653CAN
# 653CACA
# 653CACB
# 653CAOG
# 653CAC
# 653CAO
# 654CBN
# 654CBCA
# 654CBCB
# 654CBOG
# 654CBC
# 654CBO
# 655CGN
# 655CGCA
# 655CGCB
# 655CGOG
# 655CGO
# 656CD1N
# 656CD1OG
# 657CD2N
# 657CD2CA
# 657CD2CB
# 657CD2OG
# 657CD2C
# 657CD2O
# 658CN
# 658CCA
# 658CCB
# 658COG
# 658CC
# 658CO
# 659ON
# 659OCA
# 659OCB
# 659OOG
# 659OC
# 659OO
# 652NN
# 652NCD
# 652NCA
# 652NC
# 652NO
# 653CAN
# 653CACD
# 653CACA
# 653CAC
# 653CAO
# 658CN
# 658CCD
# 658CCA
# 658CC
# 658CO
# 659ON
# 659OCD
# 659OCA
# 659OC
# 659OO
# 652NN
# 652NCA
# 652NCB
# 652NOG1
# 652NCG2
# 653CAN
# 653CACA
# 653CACB
# 653CAOG1
# 653CACG2
# 654CBOG1
# 655CGOG1
# 658CN
# 658CCA
# 658CCB
# 658COG1
# 658CCG2
# 658CC
# 659ON
# 659OCA
# 659OCB
# 659OOG1
# 659OCG2
# 659OC
# 652NN
# 652NCA
# 652NCB
# 652NOG
# 652NC
# 653CAN
# 653CACA
# 653CACB
# 653CAOG
# 653CAC
# 653CAO
# 654CBN
# 654CBCA
# 654CBCB
# 654CBOG
# 654CBC
# 654CBO
# 655CGN
# 655CGCA
# 655CGCB
# 655CGOG
# 656CD1N
# 656CD1OG
# 657CD2N
# 657CD2CA
# 657CD2CB
# 657CD2OG
# 657CD2O
# 658CN
# 658CCA
# 658CCB
# 658COG
# 658CC
# 658CO
# 659ON
# 659OCA
# 659OCB
# 659OOG
# 659OC
# 659OO
# 658CN
# 658COE1
# 659ON
# 659OCA
# 659OCG
# 659OCD
# 659OOE1
# 659OCD1
# 659OCE1
# 652NO
# 653CAC
# 653CAO
# 654CBO
# 652NC
# 652NO
# 653CACA
# 653CAC
# 653CAO
# 654CBC
# 654CBO
# 657CD2C
# 657CD2O
# 658CN
# 658CCA
# 658CC
# 658CO
# 659ON
# 659OCA
# 659OCB
# 659OC
# 659OO
# 652NN
# 652NCA
# 652NCB
# 652NCG
# 652NND1
# 652NCD2
# 652NNE2
# 652NCE1
# 652NC
# 653CAN
# 653CACA
# 653CACB
# 653CACG
# 653CAND1
# 653CACD2
# 653CANE2
# 653CACE1
# 653CAC
# 654CBN
# 654CBCA
# 654CBCB
# 654CBCG
# 654CBND1
# 654CBCD2
# 654CBNE2
# 654CBCE1
# 655CGN
# 655CGCA
# 655CGCB
# 655CGCG
# 655CGND1
# 655CGCD2
# 655CGNE2
# 655CGCE1
# 656CD1CG
# 656CD1CD2
# 656CD1NE2
# 656CD1CE1
# 657CD2N
# 657CD2CA
# 657CD2CB
# 657CD2CG
# 657CD2ND1
# 657CD2CD2
# 657CD2NE2
# 657CD2CE1
# 657CD2C
# 658CN
# 658CCA
# 658CCB
# 658CCG
# 658CND1
# 658CCD2
# 658CNE2
# 658CCE1
# 658CC
# 659ON
# 659OCA
# 659OCB
# 659OCG
# 659OND1
# 659OCD2
# 659ONE2
# 659OCE1
# 659OC
# 659OO
# 652NN
# 652NCB
# 652NCG
# 652NCD2
# 652NCE1
# 652NCE2
# 652NCZ
# 653CAN
# 653CACG
# 653CACD2
# 653CACE2
# 653CACZ
# 654CBCD2
# 654CBCE2
# 657CD2N
# 657CD2CD2
# 657CD2CE2
# 658CN
# 658CCG
# 658CCD2
# 658CCE2
# 658CCZ
# 659ON
# 659OCG
# 659OCD2
# 659OCE1
# 659OCE2
# 659OCZ
# 664CDCA
# 664CDC
# 665NECA
# 665NECB
# 665NECD2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZC
# 666CZO
# 660NCG
# 660NCD2
# 660NCE2
# 660NCZ
# 660NC
# 660NO
# 661CACB
# 661CACG
# 661CACD1
# 661CACD2
# 661CACE1
# 661CACE2
# 661CACZ
# 661CAC
# 661CAO
# 662CBCA
# 662CBCB
# 662CBCG
# 662CBCD1
# 662CBCD2
# 662CBCE1
# 662CBCE2
# 662CBCZ
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGCG
# 663CGCD1
# 663CGCD2
# 663CGCE1
# 663CGCE2
# 663CGCZ
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDCD1
# 664CDCD2
# 664CDCE1
# 664CDCE2
# 664CDCZ
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NECD1
# 665NECD2
# 665NECE1
# 665NECE2
# 665NECZ
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZCE1
# 666CZCE2
# 666CZCZ
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669CCG
# 669CCD1
# 669CCD2
# 669CCE1
# 669CCE2
# 669CCZ
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OCD1
# 670OCD2
# 670OCE1
# 670OCE2
# 670OCZ
# 670OC
# 670OO
# 660NCA
# 660NCG
# 660NC
# 661CAN
# 661CACA
# 661CACB
# 661CACG
# 661CANE2
# 661CAC
# 662CBN
# 662CBCA
# 662CBCB
# 662CBCG
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGCG
# 663CGC
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NECD
# 665NEOE1
# 665NENE2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD
# 666CZOE1
# 666CZNE2
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669CCG
# 669CCD
# 669CNE2
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OCD
# 670ONE2
# 670OC
# 670OO
# 660NN
# 660NCD
# 660NCA
# 660NCB
# 660NCG
# 661CAN
# 661CACD
# 661CACA
# 661CACB
# 661CACG
# 662CBN
# 662CBCD
# 662CBCA
# 662CBCB
# 662CBCG
# 662CBC
# 663CGN
# 663CGCD
# 663CGCA
# 663CGCB
# 663CGCG
# 664CDN
# 664CDCD
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDC
# 665NEN
# 665NECD
# 665NECA
# 665NECB
# 665NECG
# 665NEC
# 665NEO
# 666CZN
# 666CZCD
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZC
# 666CZO
# 669CN
# 669CCD
# 669CCA
# 669CCB
# 669CCG
# 669CC
# 670ON
# 670OCD
# 670OCA
# 670OCB
# 670OCG
# 660NN
# 661CAN
# 662CBN
# 664CDN
# 665NEN
# 665NECA
# 666CZN
# 666CZCA
# 666CZCB
# 666CZC
# 669CN
# 660NO
# 661CAO
# 662CBO
# 665NEN
# 665NEO
# 666CZN
# 666CZCA
# 666CZC
# 666CZO
# 669CN
# 669CC
# 669CO
# 670OO
# 660NC
# 669CC
# 660NN
# 660NCA
# 660NCB
# 660NC
# 660NO
# 661CAN
# 661CACA
# 661CACB
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBCB
# 662CBC
# 662CBO
# 663CGCA
# 663CGCB
# 663CGC
# 663CGO
# 664CDCA
# 664CDCB
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OC
# 670OO
# 660NN
# 660NCA
# 660NCB
# 660NC
# 660NO
# 661CAN
# 661CACA
# 661CACB
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBCB
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OC
# 670OO
# 660NN
# 660NCA
# 660NCB
# 660NOG
# 660NC
# 660NO
# 661CAN
# 661CACA
# 661CACB
# 661CAOG
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBCB
# 662CBOG
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGOG
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDOG
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NEOG
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZOG
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669COG
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OOG
# 670OC
# 670OO
# 660NN
# 660NCD
# 660NCA
# 660NC
# 660NO
# 661CAN
# 661CACD
# 661CACA
# 661CACB
# 661CAC
# 661CAO
# 662CBN
# 662CBCD
# 662CBCA
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGC
# 663CGO
# 664CDN
# 664CDCD
# 664CDCA
# 664CDCB
# 664CDC
# 664CDO
# 665NEN
# 665NECD
# 665NECA
# 665NECB
# 665NECG
# 665NEC
# 665NEO
# 666CZN
# 666CZCD
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZC
# 666CZO
# 669CN
# 669CCD
# 669CCA
# 669CCB
# 669CCG
# 669CC
# 669CO
# 670ON
# 670OCD
# 670OCA
# 670OCB
# 670OCG
# 670OC
# 670OO
# 660NN
# 660NCA
# 660NCB
# 660NOG1
# 660NCG2
# 660NC
# 660NO
# 661CAN
# 661CACA
# 661CACB
# 661CAOG1
# 661CACG2
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBCB
# 662CBOG1
# 662CBCG2
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGOG1
# 663CGCG2
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDOG1
# 664CDCG2
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NEOG1
# 665NECG2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZOG1
# 666CZCG2
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669COG1
# 669CCG2
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OOG1
# 670OCG2
# 670OC
# 670OO
# 660NN
# 661CAN
# 661CACA
# 661CACB
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDCD2
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NECD2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZCE2
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OCD2
# 670OC
# 670OO
# 661CACD2
# 662CBCD2
# 663CGN
# 663CGCA
# 663CGCG
# 663CGCD2
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDCD1
# 664CDCD2
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NECD1
# 665NECD2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZC
# 666CZO
# 669CN
# 669CCG
# 669CCD2
# 670ON
# 670OCA
# 670OCG
# 670OCD2
# 661CACB
# 662CBCB
# 663CGCA
# 663CGCB
# 663CGC
# 664CDN
# 664CDCA
# 664CDCB
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZC
# 666CZO
# 669CCB
# 670OCA
# 670OCB
# 670OC
# 661CAO
# 662CBO
# 663CGN
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZC
# 666CZO
# 669CO
# 670ON
# 670OCA
# 670OC
# 670OO
# 661CAO
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZC
# 666CZO
# 669CO
# 670OC
# 670OO
# 661CACD1
# 662CBCD1
# 663CGN
# 663CGCA
# 663CGCB
# 663CGCG
# 663CGCD1
# 663CGC
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDCD1
# 664CDCD2
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NECD1
# 665NECD2
# 665NEC
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZC
# 669CCD1
# 670ON
# 670OCA
# 670OCD1
# 663CGN
# 663CGCB
# 664CDN
# 664CDCA
# 664CDCB
# 665NEN
# 665NECA
# 665NECB
# 666CZN
# 666CZCB
# 662CBCE1
# 662CBCZ
# 663CGCD1
# 663CGCE1
# 663CGCE2
# 663CGCZ
# 664CDCG
# 664CDCD1
# 664CDCD2
# 664CDCE1
# 664CDCE2
# 664CDCZ
# 665NECB
# 665NECG
# 665NECD1
# 665NECD2
# 665NECE1
# 665NECE2
# 665NECZ
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZCE1
# 666CZCE2
# 666CZCZ
# 660NCB
# 660NCG
# 660NO
# 661CACA
# 661CACB
# 661CACG
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBCB
# 662CBCG
# 662CBCD
# 662CBOE2
# 662CBC
# 662CBO
# 663CGN
# 663CGCA
# 663CGCB
# 663CGCG
# 663CGCD
# 663CGOE1
# 663CGOE2
# 663CGC
# 663CGO
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDCD
# 664CDOE1
# 664CDOE2
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NECD
# 665NEOE1
# 665NEOE2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD
# 666CZOE1
# 666CZOE2
# 666CZC
# 666CZO
# 669CCB
# 669CCG
# 669CC
# 669CO
# 670OO
# 662CBN
# 662CBCA
# 663CGN
# 663CGCA
# 663CGND2
# 663CGC
# 664CDN
# 664CDCA
# 664CDCB
# 664CDCG
# 664CDOD1
# 664CDND2
# 664CDC
# 664CDO
# 665NEN
# 665NECA
# 665NECB
# 665NECG
# 665NEOD1
# 665NEND2
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZOD1
# 666CZND2
# 666CZC
# 666CZO
# 662CBO
# 663CGO
# 664CDN
# 664CDO
# 665NEN
# 665NECA
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZC
# 666CZO
# 665NEN
# 665NECA
# 666CZN
# 666CZCA
# 666CZC
# 665NEN
# 665NEO
# 666CZN
# 666CZCA
# 666CZC
# 666CZO
# 664CDCE2
# 664CDCZ
# 665NECE1
# 665NECD2
# 665NECE2
# 665NECZ
# 666CZCA
# 666CZCG
# 666CZCD1
# 666CZCE1
# 666CZCD2
# 666CZCE2
# 666CZCZ
# 665NECE1
# 666CZCD1
# 666CZCE1
# 666CZCZ
# 660NN
# 660NCA
# 660NCB
# 660NOG
# 660NC
# 660NO
# 661CAN
# 661CACA
# 661CACB
# 661CAOG
# 661CAC
# 661CAO
# 662CBN
# 662CBCA
# 662CBCB
# 662CBOG
# 663CGN
# 663CGCA
# 663CGCB
# 663CGOG
# 664CDN
# 664CDCA
# 664CDCB
# 664CDOG
# 665NEN
# 665NECA
# 665NECB
# 665NEOG
# 666CZN
# 666CZCA
# 666CZCB
# 666CZOG
# 669CN
# 669CCA
# 669CCB
# 669COG
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OOG
# 670OC
# 670OO
# 661CAN
# 661CAOE1
# 669CN
# 669COE1
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OCD
# 670OOE1
# 670OCD2
# 670OCE2
# 664CDCG2
# 666CZCG2
# 669CCG2
# 670OCG2
# 664CDO
# 665NEO
# 666CZC
# 666CZO
# 669CC
# 669CO
# 670OC
# 670OO
# 661CACD1
# 661CACE1
# 664CDCD1
# 664CDCE1
# 666CZCA
# 666CZCD1
# 666CZCE1
# 666CZC
# 669CCA
# 669CCB
# 669CCG
# 669CCD1
# 669CCE1
# 669CC
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OCD1
# 670OCE1
# 670OCD2
# 670OCE2
# 670OCZ
# 670OC
# 670OO
# 660NC
# 660NO
# 661CAN
# 661CACB
# 661CAC
# 661CAO
# 662CBO
# 663CGO
# 664CDN
# 664CDCB
# 664CDO
# 665NEN
# 665NECB
# 665NECD1
# 665NEC
# 665NEO
# 666CZN
# 666CZCA
# 666CZCB
# 666CZCG
# 666CZCD1
# 666CZCD2
# 666CZCE1
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CCB
# 669CCG
# 669CCD1
# 669CCE1
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OCD1
# 670OCD2
# 670OCE1
# 670OC
# 670OO
# 660NC
# 660NO
# 661CAC
# 661CAO
# 666CZC
# 666CZO
# 669CN
# 669CCA
# 669CC
# 669CO
# 670ON
# 670OCA
# 670OCB
# 670OC
# 670OO
# 660NN
# 660NCA
# 660NCB
# 660NCG
# 660NND1
# 660NCD2
# 660NNE2
# 660NCE1
# 661CAN
# 661CACA
# 661CACB
# 661CACG
# 661CAND1
# 661CACD2
# 661CANE2
# 661CACE1
# 662CBCD2
# 662CBNE2
# 669CN
# 669CCA
# 669CCB
# 669CCG
# 669CND1
# 669CCD2
# 669CNE2
# 669CCE1
# 669CC
# 670ON
# 670OCA
# 670OCB
# 670OCG
# 670OND1
# 670OCD2
# 670ONE2
# 670OCE1
# 670OC
# 660NCD2
# 660NCE2
# 660NCZ
# 661CACD2
# 661CACE2
# 661CACZ
# 662CBCE2
# 665NECE2
# 665NECZ
# 666CZCD2
# 666CZCE1
# 666CZCE2
# 666CZCZ
# 669CN
# 669CCG
# 669CCD1
# 669CCD2
# 669CCE1
# 669CCE2
# 669CCZ
# 670ON
# 670OCG
# ...
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1OG
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2CB
# 570CD2C
# 570CD2O
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1OG
# 572CE1C
# 572CE1O
# 573CN
# 573CCA
# 573CCB
# 573COG
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OOG
# 574OC
# 574OO
# 565NN
# 565NCA
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBC
# 567CBO
# 568CGN
# 568CGCA
# 568CGC
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2C
# 571NE2N
# 571NE2CA
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1C
# 572CE1O
# 573CN
# 573CCA
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OC
# 574OO
# 565NN
# 565NCA
# 565NCB
# 565NSG
# 565NC
# 565NO
# 566CAN
# 567CBN
# 568CGN
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1SG
# 569ND1C
# 569ND1O
# 570CD2N
# 571NE2N
# 572CE1N
# 572CE1CA
# 572CE1C
# 572CE1O
# 573CN
# 565NOG
# 565NN
# 565NCA
# 565NCB
# 565NCG
# 565NCD1
# 565NCE1
# 565NCD2
# 565NCE2
# 565NCZ
# 565NC
# 565NO
# 566CACA
# 566CACB
# 566CACG
# 566CACD1
# 566CACE1
# 566CACD2
# 566CACE2
# 566CACZ
# 566CAC
# 566CAO
# 567CBCB
# 567CBCG
# 567CBCD1
# 567CBCE1
# 567CBCD2
# 567CBCE2
# 567CBCZ
# 567CBC
# 567CBO
# 568CGCA
# 568CGCB
# 568CGCG
# 568CGCD1
# 568CGCE1
# 568CGCD2
# 568CGCE2
# 568CGCZ
# 568CGC
# 568CGO
# 569ND1CA
# 569ND1CB
# 569ND1CG
# 569ND1CD1
# 569ND1CE1
# 569ND1CD2
# 569ND1CE2
# 569ND1CZ
# 569ND1C
# 569ND1O
# 570CD2CB
# 570CD2CG
# 570CD2CD1
# 570CD2CE1
# 570CD2CD2
# 570CD2CE2
# 570CD2CZ
# 570CD2C
# 570CD2O
# 571NE2CA
# 571NE2CB
# 571NE2CG
# 571NE2CD1
# 571NE2CE1
# 571NE2CD2
# 571NE2CE2
# 571NE2CZ
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1CD1
# 572CE1CE1
# 572CE1CD2
# 572CE1CE2
# 572CE1CZ
# 572CE1C
# 572CE1O
# 573CCB
# 573CCG
# 573CCD1
# 573CCE1
# 573CCD2
# 573CCE2
# 573CCZ
# 573CC
# 573CO
# 574OCB
# 574OCG
# 574OCD1
# 574OCE1
# 574OCD2
# 574OCE2
# 574OCZ
# 574OO
# 565NN
# 565NCA
# 565NCB
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBC
# 567CBO
# 568CGN
# 568CGCA
# 568CGCB
# 568CGC
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1CG
# 569ND1CD2
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2C
# 570CD2O
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1CD2
# 572CE1C
# 572CE1O
# 573CC
# 573CO
# 574OC
# 574OO
# 565NN
# 565NCA
# 565NCB
# 565NOG
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CACB
# 566CAOG
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBCB
# 567CBOG
# 567CBC
# 567CBO
# 568CGN
# 568CGCA
# 568CGCB
# 568CGOG
# 568CGC
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1OG
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2CB
# 570CD2OG
# 570CD2C
# 570CD2O
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2OG
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1OG
# 572CE1C
# 572CE1O
# 573CN
# 573CCA
# 573CCB
# 573COG
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OOG
# 574OC
# 574OO
# 565NN
# 565NCA
# 565NCB
# 565NCG
# 565NCD
# 565NOE1
# 565NNE2
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CACB
# 566CACG
# 566CACD
# 566CAOE1
# 566CANE2
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBCB
# 567CBCG
# 567CBCD
# 567CBOE1
# 567CBNE2
# 567CBC
# 567CBO
# 568CGN
# 568CGCA
# 568CGCB
# 568CGCG
# 568CGCD
# 568CGOE1
# 568CGNE2
# 568CGC
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1CG
# 569ND1CD
# 569ND1OE1
# 569ND1NE2
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2CB
# 570CD2CG
# 570CD2CD
# 570CD2OE1
# 570CD2NE2
# 570CD2C
# 570CD2O
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2CG
# 571NE2CD
# 571NE2OE1
# 571NE2NE2
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1CD
# 572CE1OE1
# 572CE1NE2
# 572CE1C
# 572CE1O
# 573CN
# 573CCA
# 573CCB
# 573CCG
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OCG
# 574OC
# 565NN
# 565NCA
# 565NCB
# 565NCG
# 565NOD1
# 565NND2
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CACB
# 566CACG
# 566CAOD1
# 566CAND2
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBCB
# 567CBCG
# 567CBOD1
# 567CBND2
# 567CBC
# 567CBO
# 568CGN
# 568CGCA
# 568CGCB
# 568CGCG
# 568CGOD1
# 568CGND2
# 568CGC
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1CG
# 569ND1OD1
# 569ND1ND2
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2CB
# 570CD2CG
# 570CD2OD1
# 570CD2ND2
# 570CD2C
# 570CD2O
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2CG
# 571NE2OD1
# 571NE2ND2
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1OD1
# 572CE1ND2
# 572CE1C
# 572CE1O
# 573CN
# 573CCA
# 573CCB
# 573CCG
# 573COD1
# 573CND2
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OCG
# 574OOD1
# 574OND2
# 574OC
# 565NN
# 565NCA
# 565NCB
# 565NCG
# 565NCD
# 565NCE
# 565NNZ
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CACB
# 566CACG
# 566CACD
# 566CACE
# 566CANZ
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBCB
# 567CBCG
# 567CBCD
# 567CBCE
# 567CBNZ
# 567CBC
# 567CBO
# 568CGN
# 568CGCA
# 568CGCB
# 568CGCG
# 568CGCD
# 568CGCE
# 568CGNZ
# 568CGC
# 568CGO
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1CG
# 569ND1CD
# 569ND1CE
# 569ND1NZ
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CA
# 570CD2CB
# 570CD2CG
# 570CD2CD
# 570CD2CE
# 570CD2NZ
# 570CD2C
# 570CD2O
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2CG
# 571NE2CD
# 571NE2CE
# 571NE2NZ
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1CD
# 572CE1CE
# 572CE1NZ
# 572CE1C
# 572CE1O
# 573CN
# 573CCA
# 573CCB
# 573CCG
# 573CCD
# 573CCE
# 573CNZ
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OCG
# 574OCD
# 574OCE
# 574ONZ
# 574OC
# 574OO
# 565NN
# 565NCA
# 565NC
# 566CAN
# 566CACA
# 566CAC
# 567CBN
# 568CGN
# 568CGCD
# 568CGCA
# 568CGC
# 569ND1N
# 569ND1CD
# 569ND1CA
# 569ND1CB
# 569ND1C
# 569ND1O
# 570CD2N
# 570CD2CD
# 570CD2CA
# 570CD2C
# 571NE2N
# 571NE2CD
# 571NE2CA
# 571NE2CB
# 571NE2CG
# 571NE2C
# 571NE2O
# 572CE1N
# 572CE1CD
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1C
# 572CE1O
# 565NN
# 565NCA
# 565NCB
# 565NCG
# 565NCD
# 565NCE
# 566CAN
# 566CACA
# 566CACB
# 566CACG
# 566CACD
# 566CACE
# 567CBN
# 567CBCB
# 567CBCG
# 567CBCD
# 568CGN
# 568CGCA
# 568CGCB
# 568CGCG
# 568CGCD
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1CG
# 569ND1CD
# 570CD2N
# 570CD2CA
# 570CD2CB
# 570CD2CG
# 570CD2CD
# 571NE2N
# 571NE2CA
# 571NE2CB
# 571NE2CG
# 571NE2CD
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1CD
# 573CN
# 573CCB
# 573CCG
# 573CCD
# 573CCE
# 574ON
# 574OCA
# 574OCB
# 574OCG
# 574OCD
# 574OCE
# 565NCD
# 565NNE
# 565NCZ
# 566CACD
# 566CANE
# 566CACZ
# 567CBCD
# 567CBNE
# 567CBCZ
# 568CGCG
# 568CGCD
# 568CGNE
# 568CGCZ
# 569ND1CB
# 569ND1CG
# 569ND1CD
# 569ND1NE
# 569ND1CZ
# 570CD2CG
# 570CD2CD
# 570CD2NE
# 570CD2CZ
# 571NE2CB
# 571NE2CG
# 571NE2CD
# 571NE2NE
# 571NE2CZ
# 572CE1N
# 572CE1CA
# 572CE1CB
# 572CE1CG
# 572CE1CD
# 572CE1NE
# 572CE1CZ
# 572CE1O
# 569ND1O
# 571NE2O
# 572CE1C
# 572CE1O
# 565NCD2
# 565NCE1
# 565NCE2
# 565NCZ
# 566CACE2
# 566CACZ
# 567CBCE2
# 567CBCZ
# 568CGCD2
# 568CGCE2
# 568CGCZ
# 569ND1CG
# 569ND1CD1
# 569ND1CD2
# 569ND1CE1
# 569ND1CE2
# 569ND1CZ
# 570CD2CE2
# 570CD2CZ
# 571NE2CD2
# 571NE2CE1
# 571NE2CE2
# 571NE2CZ
# 572CE1CG
# 572CE1CD1
# 572CE1CD2
# 572CE1CE1
# 572CE1CE2
# 572CE1CZ
# 565NN
# 565NCB
# 565NCG
# 565NCD1
# 565NC
# 565NO
# 565NCB
# 565NOG1
# 565NCG2
# 566CACB
# 566CAOG1
# 566CACG2
# 567CBCG2
# 573CCB
# 573COG1
# 573CCG2
# 573CO
# 574OCA
# 574OCB
# 574OOG1
# 574OCG2
# 574OO
# 565NCB
# 565NCG
# 565NCD1
# 565NCD2
# 566CACG
# 566CACD1
# 566CACD2
# 567CBCD1
# 573CCB
# 573CCG
# 573CCD1
# 573CCD2
# 574OCG
# 574OCD1
# 565NN
# 565NCA
# 565NCG
# 565NND2
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CACB
# 566CACG
# 566CAOD1
# 566CAND2
# 566CAC
# 566CAO
# 567CBND2
# 567CBC
# 567CBO
# 573CN
# 573CCA
# 573CCB
# 573CCG
# 573COD1
# 573CND2
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OCG
# 574OOD1
# 574OND2
# 574OC
# 574OO
# 565NN
# 565NCA
# 565NCB
# 565NOG
# 565NC
# 565NO
# 566CAN
# 566CACA
# 566CACB
# 566CAOG
# 566CAC
# 566CAO
# 567CBN
# 567CBCA
# 567CBCB
# 567CBOG
# 568CGN
# 568CGCA
# 568CGCB
# 568CGOG
# 569ND1N
# 569ND1CA
# 569ND1CB
# 569ND1OG
# 570CD2CB
# 570CD2OG
# 571NE2CB
# 571NE2OG
# 572CE1CA
# 572CE1CB
# 572CE1OG
# 573CN
# 573CCA
# 573CCB
# 573COG
# 573CC
# 573CO
# 574ON
# 574OCA
# 574OCB
# 574OOG
# 574OC
# 574OO
# 565NN
# 575NC
# 575NO
# 576CAO
# 577CBC
# 577CBO
# 578OGO
# 575NN
# 575NCA
# 575NCB
# 575NOG1
# 575NCG2
# 575NC
# 575NO
# 576CAN
# 576CACA
# 576CACB
# 576CAOG1
# 576CACG2
# 576CAC
# 576CAO
# 577CBN
# 577CBCA
# 577CBCB
# 577CBOG1
# 577CBCG2
# 577CBC
# 577CBO
# 578OGN
# 578OGCA
# 578OGCB
# 578OGOG1
# 578OGCG2
# 578OGC
# 578OGO
# 579CN
# 579CCA
# 579CCB
# 579COG1
# 579CCG2
# 579CC
# 579CO
# 580OCA
# 580OCB
# 580OCG2
# 580OC
# 580OO
# 575NN
# 575NCA
# 575NCB
# 575NOG
# 575NC
# 575NO
# 576CAN
# 576CACA
# 576CACB
# 576CAOG
# 576CAC
# 576CAO
# 577CBN
# 577CBCA
# 577CBCB
# 577CBOG
# 577CBC
# 577CBO
# 578OGN
# 578OGCA
# 578OGCB
# 578OGC
# 578OGO
# 579CN
# 579CCA
# 579CCB
# 579COG
# 579CC
# 579CO
# 580ON
# 580OCA
# 580OCB
# 580OOG
# 580OC
# 580OO
# 575NN
# 575NCA
# 575NC
# 575NO
# 576CAN
# 576CACA
# 576CAC
# 577CBN
# 577CBCA
# 578OGN
# 579CN
# 579CCA
# 579CC
# 579CO
# 580ON
# 580OCA
# 575NCB
# 576CAN
# 576CACA
# 576CACB
# 576CAOG
# 577CBN
# 577CBCA
# 577CBCB
# 577CBOG
# 578OGCB
# 578OGOG
# 579CN
# 579CCA
# 579CCB
# 579COG
# 579CC
# 579CO
# 580ON
# 580OCA
# 580OCB
# 580OOG
# 580OC
# 580OO
# 579CN
# 581NC
# 581NO
# 583CBCB
# 583CBC
# 583CBO
# 584CGCA
# 584CGCB
# 584CGC
# 584CGO
# 585CDCA
# 585CDCB
# 585CDC
# 585CDO
# 586OE1CB
# 586OE1C
# 586OE1O
# 587NE2CA
# 587NE2CB
# 587NE2CG
# 587NE2C
# 587NE2O
# 581NN
# 581NCA
# 581NCB
# 581NOG1
# 581NCG2
# 581NC
# 581NO
# 582CAN
# 582CACA
# 582CACB
# 582CAOG1
# 582CACG2
# 582CAC
# 582CAO
# 583CBN
# 583CBCA
# 583CBCB
# 583CBOG1
# 583CBCG2
# 583CBC
# 583CBO
# 584CGN
# 584CGCA
# 584CGCB
# 584CGOG1
# 584CGCG2
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDOG1
# 585CDCG2
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1OG1
# 586OE1CG2
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2OG1
# 587NE2CG2
# 587NE2C
# 587NE2O
# 588CN
# 588CCA
# 588CCB
# 588CCG2
# 588CC
# 588CO
# 589OCA
# 589OCB
# 589OCG2
# 589OC
# 589OO
# 581NN
# 581NCA
# 581NCB
# 581NOG
# 581NC
# 581NO
# 582CAN
# 582CACA
# 582CACB
# 582CAOG
# 582CAC
# 582CAO
# 583CBN
# 583CBCA
# 583CBCB
# 583CBOG
# 583CBC
# 583CBO
# 584CGN
# 584CGCA
# 584CGCB
# 584CGOG
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDOG
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1OG
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2OG
# 587NE2C
# 587NE2O
# 588CN
# 588CCA
# 588CCB
# 588COG
# 588CC
# 588CO
# 589ON
# 589OCA
# 589OCB
# 589OOG
# 589OC
# 589OO
# 581NN
# 581NCA
# 581NC
# 581NO
# 582CAN
# 582CACA
# 582CAC
# 582CAO
# 583CBN
# 583CBCA
# 583CBC
# 583CBO
# 584CGN
# 584CGCA
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2C
# 587NE2O
# 588CN
# 588CCA
# 588CC
# 588CO
# 589ON
# 589OCA
# 589OO
# 581NN
# 583CBN
# 584CGN
# 584CGCA
# 584CGCB
# 584CGSG
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDSG
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1SG
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2SG
# 587NE2C
# 587NE2O
# 583CBOG
# 584CGN
# 584CGCA
# 584CGCB
# 584CGOG
# 585CDN
# 585CDCA
# 585CDCB
# 585CDOG
# 585CDC
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1OG
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2OG
# 587NE2C
# 587NE2O
# 588COG
# 584CGCE1
# 584CGCZ
# 585CDCG
# 585CDCD1
# 585CDCD2
# 585CDCE1
# 585CDCE2
# 585CDCZ
# 586OE1CG
# 586OE1CD1
# 586OE1CD2
# 586OE1CE1
# 586OE1CE2
# 586OE1CZ
# 587NE2CB
# 587NE2CG
# 587NE2CD1
# 587NE2CD2
# 587NE2CE1
# 587NE2CE2
# 587NE2CZ
# 585CDC
# 585CDO
# 586OE1CA
# 586OE1C
# 586OE1O
# 587NE2CA
# 587NE2C
# 587NE2O
# 581NCB
# 581NCG
# 581NCD1
# 581NCE1
# 581NCD2
# 581NCE2
# 581NCZ
# 582CACB
# 582CACG
# 582CACD1
# 582CACE1
# 582CACD2
# 582CACE2
# 582CACZ
# 582CAO
# 583CBCA
# 583CBCB
# 583CBCG
# 583CBCD1
# 583CBCE1
# 583CBCD2
# 583CBCE2
# 583CBCZ
# 583CBC
# 583CBO
# 584CGN
# 584CGCA
# 584CGCB
# 584CGCG
# 584CGCD1
# 584CGCE1
# 584CGCD2
# 584CGCE2
# 584CGCZ
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDCG
# 585CDCD1
# 585CDCE1
# 585CDCD2
# 585CDCE2
# 585CDCZ
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1CG
# 586OE1CD1
# 586OE1CE1
# 586OE1CD2
# 586OE1CE2
# 586OE1CZ
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2CG
# 587NE2CD1
# 587NE2CE1
# 587NE2CD2
# 587NE2CE2
# 587NE2CZ
# 587NE2C
# 587NE2O
# 588CCA
# 588CCB
# 588CCG
# 588CCD1
# 588CCE1
# 588CCD2
# 588CCE2
# 588CCZ
# 588CC
# 588CO
# 589OCB
# 589OCG
# 589OCD1
# 589OCE1
# 589OCD2
# 589OCE2
# 589OCZ
# 589OO
# 581NO
# 582CAO
# 583CBC
# 583CBO
# 584CGN
# 584CGCA
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2C
# 587NE2O
# 588CC
# 588CO
# 581NN
# 581NCA
# 581NCB
# 581NOG
# 581NC
# 582CACA
# 582CACB
# 582CAOG
# 583CBN
# 583CBCA
# 583CBCB
# 583CBOG
# 584CGN
# 584CGCA
# 584CGCB
# 584CGOG
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDOG
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1OG
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2OG
# 587NE2C
# 587NE2O
# 588CN
# 588CCA
# 588CCB
# 588COG
# 589OCB
# 589OOG
# 581NN
# 584CGN
# 585CDN
# 585CDCA
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1C
# 587NE2N
# 581NCB
# 581NCG
# 581NOD1
# 581NND2
# 582CACG
# 582CAOD1
# 582CAND2
# 583CBCG
# 583CBOD1
# 583CBND2
# 584CGCG
# 584CGOD1
# 584CGND2
# 585CDN
# 585CDCB
# 585CDCG
# 585CDOD1
# 585CDND2
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1CG
# 586OE1OD1
# 586OE1ND2
# 586OE1C
# 587NE2CG
# 587NE2OD1
# 587NE2ND2
# 588CCB
# 588CCG
# 588COD1
# 588CND2
# 589OCG
# 589OOD1
# 589OND2
# 584CGCG
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDCG
# 585CDCD
# 585CDCE
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1CG
# 586OE1CD
# 586OE1CE
# 586OE1NZ
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CG
# 587NE2CD
# 587NE2C
# 587NE2O
# 588CCG
# 588CCD
# 588CCE
# 588CO
# 589OCG
# 589OCD
# 589OCE
# 585CDN
# 585CDCA
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2C
# 587NE2O
# 581NCB
# 581NCG
# 581NCD
# 581NCE
# 582CACB
# 582CACG
# 582CACD
# 582CACE
# 582CANZ
# 583CBCA
# 583CBCB
# 583CBCG
# 583CBCD
# 583CBCE
# 583CBNZ
# 584CGN
# 584CGCA
# 584CGCB
# 584CGCG
# 584CGCD
# 584CGCE
# 584CGNZ
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDCG
# 585CDCD
# 585CDCE
# 585CDNZ
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1CG
# 586OE1CD
# 586OE1CE
# 586OE1NZ
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2CG
# 587NE2CD
# 587NE2CE
# 587NE2NZ
# 587NE2C
# 587NE2O
# 588CN
# 588CCA
# 588CCB
# 588CCG
# 588CCD
# 588CCE
# 588CNZ
# 589ON
# 589OCA
# 589OCB
# 589OCG
# 589OCD
# 589OCE
# 589ONZ
# 585CDN
# 586OE1N
# 586OE1CA
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2C
# 587NE2O
# 584CGC
# 584CGO
# 585CDC
# 585CDO
# 586OE1C
# 586OE1O
# 587NE2CA
# 587NE2CB
# 587NE2OG
# 587NE2C
# 587NE2O
# 583CBCA
# 583CBC
# 584CGN
# 584CGCA
# 584CGCB
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1C
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2C
# 587NE2O
# 581NN
# 581NCA
# 581NCB
# 581NCG
# 581NCD1
# 581NCD2
# 581NC
# 581NO
# 582CAN
# 582CACA
# 582CACB
# 582CACG
# 582CACD1
# 582CACD2
# 582CAC
# 582CAO
# 583CBN
# 583CBCA
# 583CBCB
# 583CBCG
# 583CBCD1
# 583CBCD2
# 583CBC
# 583CBO
# 584CGN
# 584CGCA
# 584CGCB
# 584CGCG
# 584CGCD1
# 584CGCD2
# 584CGC
# 584CGO
# 585CDN
# 585CDCA
# 585CDCB
# 585CDCG
# 585CDCD1
# 585CDCD2
# 585CDC
# 585CDO
# 586OE1N
# 586OE1CA
# 586OE1CB
# 586OE1CG
# 586OE1CD1
# 586OE1CD2
# 586OE1C
# 586OE1O
# 587NE2N
# 587NE2CA
# 587NE2CB
# 587NE2CG
# 587NE2CD1
# 587NE2CD2
# 587NE2C
# 587NE2O
# 588CCB
# 588CCG
# 588CCD1
# 589OCB
# 589OCG
# 589OCD1
# 583CBN
# 584CGN
# 584CGCA
# 584CGOG
# 584CGC
# 585CDN
# 585CDCA
# 586OE1N
# 587NE2N
# 587NE2CA
# 587NE2OG
# 587NE2C
# 583CBN
# 584CGN
# 584CGCA
# 585CDN
# 587NE2N
# 583CBN
# 583CBCA
# 583CBOG
# 584CGN
# 584CGCA
# 584CGCB
# 584CGOG
# 585CDN
# 585CDCA
# 587NE2N
# 587NE2CA
# 587NE2OG
# 587NE2C
# 587NE2O
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-21d4e6c87ce9> in <module>()
#     148
#     149 if __name__ == '__main__':
# --> 150     main()
#
# <ipython-input-42-21d4e6c87ce9> in main()
#     110                     if chain1!=chain2 and chain2 not in chain_used:
#     111                         chain_used.append(chain1)
# --> 112                         comp=calc_dist_matrix(chain1, chain2, outfile,comp) #Makes coord files for matlab and returns a dict for alpha complex
#     113                         #element_classification(outfile,comp)
#     114                         #calculate_alpha_complex(BarCollection, name, alphaprot, cwd) #Calculates alpha complex
#
# <ipython-input-41-35e2bb0ac2e6> in calc_dist_matrix(chain_one, chain_two, outfile, alphaprot)
#      49         for col, residue_two in enumerate(chain_two) :
#      50
# ---> 51             alphaprot=calc_residue_dist(residue_one, residue_two, outfile, atom1_used, atom2_used, alphaprot)
#      52
#      53     return(alphaprot)
#
# <ipython-input-41-35e2bb0ac2e6> in calc_residue_dist(residue1, residue2, outfile, atom1_used, atom2_used, alphaprot)
#       4         for atom2 in residue2:
#       5
# ----> 6             distance=atom1-atom2
#       7
#       8             if distance>20:#If the residues is to far from eachother there is no need to calculate the distance for the rest of the atoms
#
# C:\Users\joaki\Anaconda2\lib\site-packages\Bio\PDB\Atom.pyc in __sub__(self, other)
#     123         """
#     124         diff = self.coord - other.coord
# --> 125         return numpy.sqrt(numpy.dot(diff, diff))
#     126
#     127     # set methods
#
# KeyboardInterrupt:

# %% [markdown]
# def calc_residue_dist(residue1, residue2, outfile, atom1_used, atom2_used, alphaprot) :
#
#     for atom1 in residue1:
#         for atom2 in residue2:
#
#             distance=atom1-atom2
#
#             if distance>20:#If the residues is to far from eachother there is no need to calculate the distance for the rest of the atoms
#                 return(alphaprot)
#             if distance >12:#Go to the next atom
#                 continue
#
#             if 'H' not in atom1.get_id() and 'H' not in atom2.get_id(): # DUBBELKOLLA ATT DET INTE FINNS H I ANDRA!!!!
#             #if atom1.get_id() != 'H' and atom2.get_id() != 'H':
#
#                 a1_serial=str(atom1.serial_number)
#                 a2_serial=str(atom1.serial_number)
#                 if a1_serial not in atom1_used:
#                     atom1_used.append(a1_serial)
#                     x=str(atom1.get_coord()[0])
#                     y=str(atom1.get_coord()[1])
#                     z=str(atom1.get_coord()[2])
#                     if 'C' in atom1.get_name():# and
#                         outfile.write('0'+' '+'1'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('C', []).append(x+','+y+','+z)
#                     elif 'O' in atom1.get_name():
#                         outfile.write('0'+' '+'2'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('O', []).append(x+','+y+','+z)
#                     elif 'N' in atom1.get_name():
#                         outfile.write('0'+' '+'3'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('N', []).append(x+','+y+','+z)
#                     elif 'S' in atom1.get_name():
#                         outfile.write('0'+' '+'4'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('S', []).append(x+','+y+','+z)
#                 if a2_serial not in atom2_used:
#                     atom2_used.append(a2_serial)
#                     x=str(atom2.get_coord()[0])
#                     y=str(atom2.get_coord()[1])
#                     z=str(atom2.get_coord()[2])
#                     if 'C' in atom1.get_name():
#                         outfile.write('1'+' '+'1'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('C', []).append(x+','+y+','+z)
#                     elif 'O' in atom1.get_name():
#                         outfile.write('1'+' '+'2'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('O', []).append(x+','+y+','+z)
#                     elif 'N' in atom1.get_name():
#                         outfile.write('1'+' '+'3'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('N', []).append(x+','+y+','+z)
#                     elif 'S' in atom1.get_name():
#                         outfile.write('1'+' '+'4'+' '+x+' '+y+' '+z+'\n')
#                         alphaprot.setdefault('S', []).append(x+','+y+','+z)
#
#     return(alphaprot)
#
#
#
#
# def calc_dist_matrix(chain_one, chain_two,outfile,alphaprot) :
#
#     atom1_used=[]
#     atom2_used=[]
#     for row, residue_one in enumerate(chain_one) :
#         for col, residue_two in enumerate(chain_two) :
#
#             alphaprot=calc_residue_dist(residue_one, residue_two, outfile, atom1_used, atom2_used, alphaprot)
#
#     return(alphaprot)
