# %%
import Bio
from Bio.PDB import *
import sys
import re
import matplotlib.pyplot as plt
from matplotlib import cm
import math
import numpy as np
import os

import pandas

# %%
def calc_residue_dist(residue1, residue2,layers) :
    """Returns the C-alpha distance between two residues"""
    for atom1 in residue1:
        for atom2 in residue2:
            
            distance=atom1-atom2    

            if distance>20:#If the residues is to far from eachother there is no need to calculate the distance for the rest of the atoms
                return (layers)
            if distance >8:#Go to the next atom
                continue
            if distance<=0.5:
                layers.setdefault('VDW', []).append([str(residue1.get_full_id()[3][1]) +'.'+ residue1.get_resname() +'-'+ str(residue2.get_full_id()[3][1]) +'.'+ residue2.get_resname(),atom1.get_name() +'-'+ atom2.get_name(), distance])

                
            if 'H' not in atom1.get_id() and 'H' not in atom2.get_id(): # DUBBELKOLLA ATT DET INTE FINNS H I ANDRA!!!!
            #if atom1.get_id() != 'H' and atom2.get_id() != 'H':    
                if atom1.get_name()=='CA' and atom2.get_name()=='CA' and distance<=8: #CA-CA distance
                    layers.setdefault('CA-CA', []).append([str(residue1.get_full_id()[3][1]) +'.'+ residue1.get_resname() +'-'+ str(residue2.get_full_id()[3][1]) +'.'+ residue2.get_resname(),atom1.get_name() +'-'+ atom2.get_name(), distance])
                if distance<=5: #Heavy atoms distance
                    layers.setdefault('H-A', []).append([str(residue1.get_full_id()[3][1]) +'.'+ residue1.get_resname() +'-'+ str(residue2.get_full_id()[3][1]) +'.'+ residue2.get_resname(),atom1.get_name() +'-'+ atom2.get_name(), distance])
    return (layers)



def calc_dist_matrix(chain_one, chain_two,layers) :
    """Returns a matrix of C-alpha distances between two chains"""
    answer = np.zeros((len(chain_one), len(chain_two)), np.float)
    for row, residue_one in enumerate(chain_one) :
        for col, residue_two in enumerate(chain_two) :
            layers = calc_residue_dist(residue_one, residue_two,layers)
    return (layers)

# %%
def find_protein_value(pdb_name,value_file):
    import re
    #Re.search(r”([\w.]+)@([\w.]+)”, value_file)

# %%
def main():
    
    #Dir path
    #args = sys.argv[1:]
    args='D:\Downloads\CnM-dataset\MOAL_Benchmark\D1AHW' #'/home/joakim/Downloads/models' #str(args[0])
    
    pdb_list=[]
    for file in os.listdir(args):
        if file.endswith(".pdb"):
            #pdb_list.append(args+'/'+file)
            pdb_list.append([args,file])
    print pdb_list
    #filename_pdb = '/home/joakim/Downloads/*.pdb'#'/home/joakim/Downloads/2HIY_A.pdb' #'/home/joakim/Downloads/D1A2K-a0a-merged.pdb'
    
    valuefile='D:\Downloads\CnM.featuresNPqDNZ'#'/home/joakim/Downloads/CnM.featuresNPqDNZ'
    value_df=pandas.read_csv(valuefile,delim_whitespace=1)
    print(value_df)
    
    
    
    #value_file=open('/home/joakim/Downloads/CnM.featuresNPqDNZ', 'r').read().splitlines()
    #print(value_file)
    
    
    for counter, filepath_pdb in enumerate(pdb_list):
        print counter
        filename_pdb=os.path.join(pdb_list[counter][0],pdb_list[counter][1])
        print(score)
        try: 
            PDBobj = PDBParser()
            structure = PDBobj.get_structure(filename_pdb, filename_pdb)
            model = structure[0]
        except IOError: 
            print 'IO Error', filename_pdb       
            while 'true':
                input1=raw_input("Error parsing PDB file! Continue(y/n)...")
                if input1.lower()=='y':
                    continue
                elif input1.lower()=='n':
                    sys.exit()

        
        score=value_df.loc[((value_df['#'] == pdb_list[counter][1][:-11]),'CPscore')].values[0]
                    
        chain_used=[]
        layers={}
        layers.setdefault('VDW', []).append(['Check'])
        layers.setdefault('CA-CA', []).append(['Check'])
        layers.setdefault('H-A', []).append(['Check'])
        for chain1 in model:
            for chain2 in model:
                if chain1!=chain2 and chain2 not in chain_used:
                    chain_used.append(chain1)
                    layers = calc_dist_matrix(chain1, chain2,layers)
                    #contact_map = dist_matrix < 12.0

     #   t=0
     #   for i in layers['CA-CA']:
       #     t=t+1

     #   g=0
     #   for i in layers['H-A']:
      #      g=g+1

        #d=0

        #for i in layers['VDW']:
         #   d=d+1

        #print d-1
        #print g-1
        #print t-1
    #    for i in contact_map:
    #        for g in i:
    #            if g!= False:
    #                print g

    
if __name__ == '__main__':
  main()
# Out:
# [['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a0a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a0b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a0c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a0d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a100a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a100b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a100c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a100d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a101a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a101b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a101c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a101d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a102a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a102b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a102c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a102d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a103a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a103b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a103c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a103d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a104a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a104b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a104c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a104d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a105a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a105b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a105c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a105d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a106a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a106b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a106c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a106d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a107a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a107b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a107c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a107d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a108a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a108b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a108c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a108d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a109a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a109b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a109c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a109d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a10a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a10b-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a10c-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a10d-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmark\\D1AHW', 'D1AHW-a11a-merged.pdb'], ['D:\\Downloads\\CnM-dataset\\MOAL_Benchmar ...
#                 #  tarmod    rGb   nBSA  Fintres     Sc     EC   ProQ  zrank  \
# 0           T50-1   0.035  0.034  0.106    0.571  0.072  0.682  0.611  0.657
# 1           T50-2   0.033  0.036  0.124    0.579 -0.128  0.703  0.633  0.671
# 2           T50-3   0.042  0.027  0.088    0.776  0.434  0.698  0.536  0.452
# 3           T50-4   0.032  0.032  0.118    0.514  0.458  0.640  0.579  0.534
# 4           T50-5   0.040  0.029  0.102    0.336  0.172  0.708  0.589  0.839
# 5           T50-6   0.046  0.030  0.104    0.375 -0.084  0.710  0.612  0.711
# 6           T50-7   0.043  0.027  0.090    0.602  0.429  0.746  0.633  0.584
# 7           T50-8   0.041  0.014  0.058    0.575  0.051  0.715  0.622  0.682
# 8           T50-9   0.041  0.037  0.106    0.377 -0.287  0.683  0.687  0.997
# 9          T50-10   0.045  0.020  0.082    0.552  0.065  0.714  0.639  0.655
# 10         T50-11   0.035  0.040  0.116    0.401  0.026  0.704  0.739  1.000
# 11         T50-12   0.041  0.016  0.052    0.561 -0.004  0.726  0.676  0.725
# 12         T50-13   0.043  0.034  0.118    0.667  0.400  0.736  0.610  0.599
# 73781   0.927  ...   0.528  0.919  0.756  0.108  0.244  0.00511  -1  0.036574
# 73782   0.111  ...   0.555  0.911  0.582  0.104  0.372  0.00624  -1  0.032486
# 73783   0.241  ...   0.575  0.925  0.864  0.136  0.164  0.00576  -1  0.043670
# 73784   0.094  ...   0.545  0.915  0.840  0.116  0.189  0.00696  -1  0.059666
# 73785   0.427  ...   0.537  0.922  0.236  0.089  0.594  0.03027  -1  0.098916
# 73786   0.263  ...   0.555  0.912  0.812  0.112  0.450  0.02161  -1  0.149268
# 73787   0.579  ...   0.535  0.923  0.827  0.104  0.259  0.02089  -1  0.065134
# 73788   0.150  ...   0.536  0.905  0.778  0.126  0.416  0.00525  -1  0.113147
# 73789   0.112  ...   0.552  0.931  0.778  0.082  0.286  0.00613  -1  0.120374
# 73790   0.561  ...   0.589  0.932  0.794  0.106  0.310  0.00729  -1  0.119195
# 73791   0.384  ...   0.602  0.909  0.876  0.146  0.486  0.00529  -1  0.171987
#
#             pqd  pqdz
# 0      0.296439   NaN
# 1      0.220123   NaN
# 2      0.225628   NaN
# 3      0.134728   NaN
# 4      0.301145   NaN
# 5      0.277879   NaN
# 6      0.125022   NaN
# 7      0.278002   NaN
# 8      0.125676   NaN
# 9      0.405764   NaN
# 10     0.194820   NaN
# 11    -0.017054   NaN
# 12     0.163496   NaN
# 13     0.372177   NaN
# 14     0.181756   NaN
# 15     0.317956   NaN
# 16     0.087923   NaN
# 17     0.223216   NaN
# 18     0.217515   NaN
# 19     0.310756   NaN
# 20     0.237061   NaN
# 21     0.238068   NaN
# 22     0.209157   NaN
# 23     0.185024   NaN
# 24     0.070541   NaN
# 25     0.372587   NaN
# 26     0.360194   NaN
# 27     0.351106   NaN
# 28     0.050026   NaN
# 29     0.315789   NaN
# ...         ...   ...
# 73762  0.007101   NaN
# 73763  0.103058   NaN
# 73764  0.151530   NaN
# 73765  0.140553   NaN
# 73766  0.070531   NaN
# 73767 -0.028088   NaN
# 73768  0.193461   NaN
# 73769 -0.098267   NaN
# 73770  0.198318   NaN
# 73771  0.163207   NaN
# 73772  0.005491   NaN
# 73773 -0.008372   NaN
# 73774  0.113310   NaN
# 73775  0.022296   NaN
# 73776  0.106007   NaN
# 73777  0.169734   NaN
# 73778  0.053454   NaN
# 73779 -0.002850   NaN
# 73780  0.214821   NaN
# 73781  0.068337   NaN
# 73782 -0.079724   NaN
# 73783  0.032718   NaN
# 73784  0.006663   NaN
# 73785  0.058545   NaN
# 73786  0.058200   NaN
# 73787  0.097927   NaN
# 73788 -0.079831   NaN
# 73789  0.127116   NaN
# 73790  0.069135   NaN
# 73791 -0.039038   NaN
#
# [73792 rows x 21 columns]
# 0
# 0.76494
# 1
# 0.01677
# 2
# 0.01803
# 3
# 0.78973
# 4
# 0.00455
# 5
# 0.00423
# 6
# 0.00451
# 7
# 0.00425
# 8
# 0.00416
# 9
# 0.00339
# 10
# 0.00469
# 11
# 0.0046
# 12
# 0.00308
